# %%
## Importing important libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=30)
matplotlib.rcParams.update({'font.size': 28})
import math

# %% [markdown]
# # Creating Data Frames for DataSets

# %%
Covid_19_Countires_Wise = pd.read_csv('../Covid-19-Data(selected-dataset)/countries-aggregated.csv')
Blood_Pressure_Countires_Wise = pd.read_csv('../Blood Pressure/NCD_RisC_Lancet_2016_BP_age_standardised_countries.csv')
Diabetes_Countires_Wise = pd.read_csv('../Diabetes/NCD_RisC_Lancet_2016_DM_age_standardised_countries.csv')
HIV_Countires_Wise = pd.read_csv('../HIV infected Population/Data_Extract_From_Health_Nutrition_and_Population_Statistics/c600116a-af72-4faa-945a-ab00ddddb96e_Data.csv')
Medical_Expending_Countires_Wise = pd.read_csv('../Medical Expending/API_SH.XPD.CHEX.PC.CD_DS2_en_csv_v2_1218407/API_SH.XPD.CHEX.PC.CD_DS2_en_csv_v2_1218407.csv')
Population_Data_Countires_Wise = pd.read_csv('../Population Data/WPP2019_PopulationBySingleAgeSex_1950-2019.csv')
Tuber_Culosis_Countires_Wise = pd.read_csv('../TB Data/TB_notifications_2020-08-17.csv')

# %% [markdown]
# ## Utility Functions

# %%
## Visulalization function 
def Visualize(dataset,List_of_count_to_print,title1,ylab):
    df = dataset
    n = 0
    for i in List_of_count_to_print:
        filter1 = df['Country'] == i
        df = df[filter1]
        labels = df['Date']
        conf = df['Confirmed']
        Recov = df['Recovered']
        Death = df['Deaths']
        
        #high = max(conf)
        #low = min(conf)
        
        x = np.arange(len(labels))  # the x label locations 
        width = .80  # the width of the bars
        fig, ax = plt.subplots(figsize=(50,20))
        rects1 = ax.bar(x - width/2, conf, width, label='confirmed')
        rects2 = ax.bar(x + width/2, Recov, width, label='Recovered')
        rects3 = ax.bar(x + width/2, Death, width, label='Death')

        # Add some text for labels, title and custom x-axis tick labels, etc.
        ax.set_ylabel(ylab)
        ax.set_title(title1)
        ax.set_xticks(x)
        plt.xticks(rotation=90) 
        #plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
        ax.set_xticklabels(labels)
        ax.legend()
        n  = n + 1
    
    
    plt.show()
    
## function to Check the List of Countries avaialable
def count_avalaible(dataframe,country_coul_rep = 'Country'):
    x = 0
    for i in set(dataframe.loc[:,country_coul_rep]):
        print(i,end=' | ')
        x = x + 1
        if(x > 6):
            x = 0
            print()
    print("\n\n##Total No of Countries = " + str(len(set(dataframe.loc[:,country_coul_rep]))))

# %% [markdown]
# # Visualising the Diffrent Data sets

# %% [markdown]
# ## 1. Covid_19_Countires_Wise Analysis

# %%
## Check the List of Countries avaialable

count_avalaible(Covid_19_Countires_Wise,'Country')

#print(set(Covid_19_Countires_Wise['Country']))
# Out:
# Estonia | Mauritania | Barbados | Sri Lanka | Indonesia | Greece | Trinidad and Tobago |
# Ireland | Italy | Chile | Ethiopia | Papua New Guinea | Congo (Brazzaville) | Malaysia |
# Switzerland | Somalia | Cameroon | Cabo Verde | North Macedonia | Yemen | Peru |
# Pakistan | Western Sahara | Panama | Saint Vincent and the Grenadines | Qatar | Egypt | Paraguay |
# Latvia | Spain | Angola | Maldives | Mongolia | Tunisia | Saint Lucia |
# Czechia | Antigua and Barbuda | Romania | Colombia | Dominica | Germany | Israel |
# Grenada | Venezuela | Mexico | Iraq | Diamond Princess | Gabon | Uzbekistan |
# Sierra Leone | Burundi | Nicaragua | Saudi Arabia | Bulgaria | Morocco | Comoros |
# Botswana | South Sudan | United Arab Emirates | Liechtenstein | Belize | Bahamas | Namibia |
# Benin | Mozambique | Equatorial Guinea | Armenia | Slovakia | Cyprus | China |
# Ecuador | Libya | West Bank and Gaza | Azerbaijan | Guinea | Norway | Liberia |
# Lithuania | Austria | Eritrea | Australia | Kuwait | Iran | Malta |
# Tajikistan | Turkey | Dominican Republic | Andorra | Kenya | Haiti | Vietnam |
# Cuba | Kosovo | Kyrgyzstan | MS Zaandam | Sudan | Philippines | Guyana |
# Taiwan* | Bolivia | Montenegro | Lebanon | Saint Kitts and Nevis | San Marino | Belarus |
# Albania | Eswatini | Burkina Faso | Iceland | Laos | Guatemala | Bangladesh |
# Fiji | Croatia | Slovenia | Uganda | Djibouti | Niger | United Kingdom |
# Guinea-Bissau | Zambia | Hungary | Bosnia and Herzegovina | Bhutan | Honduras | Nigeria |
# Ghana | Georgia | Russia | Jamaica | Afghanistan | Brazil | Netherlands |
# Brunei | Gambia | Costa Rica | Monaco | Cote d'Ivoire | Poland | Bahrain |
# France | Burma | Moldova | India | Canada | Jordan | Rwanda |
# Thailand | Timor-Leste | Central African Republic | Serbia | Tanzania | Oman | Lesotho |
# Denmark | Mauritius | Finland | El Salvador | Sweden | South Africa | Belgium |
# Argentina | Togo | Zimbabwe | Senegal | Uruguay | Seychelles | Cambodia |
# Chad | Syria | US | Algeria | New Zealand | Korea, South | Suriname |
# Madagascar | Ukraine | Japan | Mali | Sao Tome and Principe | Holy See | Singapore |
# Kazakhstan | Malawi | Nepal | Portugal | Luxembourg | Congo (Kinshasa) |
#
# ##Total No of Countries = 188

# %%
filter1 = Covid_19_Countires_Wise['Country'] == 'US'
Covid_19_Countires_Wise_country_specific = Covid_19_Countires_Wise[filter1]
Covid_19_Countires_Wise_country_specific
#Covid_19_Countires_Wise                    ## Uncomment this to view for all countires at once
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 174    2020-01-22      US          1          0       0
# 362    2020-01-23      US          1          0       0
# 550    2020-01-24      US          2          0       0
# 738    2020-01-25      US          2          0       0
# 926    2020-01-26      US          5          0       0
# ...           ...     ...        ...        ...     ...
# 38338  2020-08-12      US    5197411    1753760  166034
# 38526  2020-08-13      US    5248958    1774648  167110
# 38714  2020-08-14      US    5313252    1796326  168452
# 38902  2020-08-15      US    5361165    1818527  169481
# 39090  2020-08-16      US    5403213    1833067  170052
#
# [208 rows x 5 columns]

# %%
#print(Covid_19_Countires_Wise)
Visualize(Covid_19_Countires_Wise , ['US'],'Spread of Covid 19','No of Patients in (millions)')

# %% [markdown]
# ## 2. Blood_Pressure_Countires_Wise

# %%
## Check the List of Countries avaialable

#Blood_Pressure_Countires_Wise

## Columns renaming for Uniformity

Blood_Pressure_Countires_Wise = Blood_Pressure_Countires_Wise.rename(columns={'Country/Region/World': 'Country'})
count_avalaible(Blood_Pressure_Countires_Wise,'Country')
# Out:
# Guinea Bissau | Estonia | Mauritania | Barbados | Sri Lanka | Viet Nam | Samoa |
# Indonesia | Greece | Trinidad and Tobago | Lao PDR | Ireland | Italy | Chile |
# Ethiopia | North Korea | Papua New Guinea | Malaysia | French Polynesia | Greenland | Switzerland |
# Somalia | Cameroon | Cabo Verde | Czech Republic | Kiribati | Yemen | Peru |
# Pakistan | Palau | Turkmenistan | Panama | Tokelau | Saint Vincent and the Grenadines | Qatar |
# Egypt | Paraguay | Latvia | Spain | Angola | Maldives | Mongolia |
# Tunisia | Saint Lucia | Tonga | Brunei Darussalam | Romania | Antigua and Barbuda | Colombia |
# Dominica | Germany | Israel | Grenada | Venezuela | Mexico | Iraq |
# Solomon Islands | Gabon | Uzbekistan | Sierra Leone | Burundi | Nicaragua | Saudi Arabia |
# Bulgaria | Morocco | Comoros | Tuvalu | Botswana | United Arab Emirates | Taiwan |
# Belize | Bahamas | Namibia | Benin | Mozambique | Equatorial Guinea | Armenia |
# Slovakia | Cyprus | China | Ecuador | Libya | Azerbaijan | Guinea |
# Norway | Liberia | Micronesia (Federated States of) | Lithuania | Austria | China (Hong Kong SAR) | Macedonia (TFYR) |
# Eritrea | Australia | Kuwait | Iran | Syrian Arab Republic | Vanuatu | Congo |
# Malta | Tajikistan | Turkey | Dominican Republic | Andorra | Kenya | Haiti |
# South Korea | Cuba | Kyrgyzstan | Myanmar | Sudan | Philippines | Guyana |
# Bolivia | Montenegro | Lebanon | Saint Kitts and Nevis | Belarus | Albania | Swaziland |
# Burkina Faso | Iceland | Guatemala | Bangladesh | Fiji | Croatia | Slovenia |
# Uganda | Djibouti | Niue | Niger | United Kingdom | Zambia | Hungary |
# Bosnia and Herzegovina | Bhutan | American Samoa | Honduras | Ghana | Nigeria | Georgia |
# Bermuda | Jamaica | Afghanistan | United States of America | Brazil | Netherlands | Gambia |
# Costa Rica | Cote d'Ivoire | Poland | Bahrain | Occupied Palestinian Territory | France | Moldova |
# India | Canada | Jordan | Rwanda | Thailand | Timor-Leste | Central African Republic |
# Serbia | Tanzania | Oman | Lesotho | Denmark | Mauritius | Cook Islands |
# Finland | El Salvador | Sweden | South Africa | Belgium | Argentina | Nauru |
# Togo | Zimbabwe | Senegal | Uruguay | Seychelles | Cambodia | Chad |
# Algeria | New Zealand | Suriname | DR Congo | Puerto Rico | Madagascar | Ukraine |
# Japan | Russian Federation | Mali | Sao Tome and Principe | Singapore | Kazakhstan | Malawi |
# Nepal | Portugal | Luxembourg | Marshall Islands |
#
# ##Total No of Countries = 200

# %%
#print(set(Blood_Pressure_Countires_Wise['Country/Region/World']))

Country_to_look_for = 'India'
ylab = "ratio"
xlab = "Year"
filter1 = Blood_Pressure_Countires_Wise['Country'] == Country_to_look_for
Blood_Pressure_Countires_Wise_country_specific = Blood_Pressure_Countires_Wise[filter1]
Blood_Pressure_Countires_Wise_country_specific                 
#Blood_Pressure_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#       Country  ISO    Sex  Year  Mean systolic blood pressure (mmHg)  \
# 3321    India  IND    Men  1975                           122.350379
# 3322    India  IND    Men  1976                           122.455017
# 3323    India  IND    Men  1977                           122.557283
# 3324    India  IND    Men  1978                           122.655957
# 3325    India  IND    Men  1979                           122.756322
# ...       ...  ...    ...   ...                                  ...
# 11557   India  IND  Women  2011                           124.516704
# 11558   India  IND  Women  2012                           124.482273
# 11559   India  IND  Women  2013                           124.437534
# 11560   India  IND  Women  2014                           124.386239
# 11561   India  IND  Women  2015                           124.329088
#
#        Mean systolic blood pressure lower 95% uncertainty interval (mmHg)  \
# 3321                                          114.041114
# 3322                                          114.618921
# 3323                                          115.219463
# 3324                                          115.878855
# 3325                                          116.518464
# ...                                                  ...
# 11557                                         122.541863
# 11558                                         122.207197
# 11559                                         121.811331
# 11560                                         121.351055
# 11561                                         120.857972
#
#        Mean systolic blood pressure upper 95% uncertainty interval (mmHg)  \
# 3321                                          130.406286
# 3322                                          129.962311
# 3323                                          129.524269
# 3324                                          129.206492
# 3325                                          128.682056
# ...                                                  ...
# 11557                                         126.440123
# 11558                                         126.696852
# 11559                                         127.014735
# 11560                                         127.362613
# 11561                                         127.739473
#
#        Mean diastolic blood pressure (mmHg)  \
# 3321                              78.007941
# 3322                              78.057072
# 3323                              78.103911
# 3324                              78.148476
# 3325                              78.193339
# ...                                     ...
# 11557                             78.669085
# 11558                             78.777913
# 11559                             78.885454
# 11560                             78.989876
# 11561                             79.091675
#
#        Mean diastolic blood pressure lower 95% uncertainty interval (mmHg)  \
# 3321                                           72.435968
# 3322                                           72.873279
# 3323                                           73.299619
# 3324                                           73.666794
# 3325                                           73.970279
# ...                                                  ...
# 11557                                          77.395098
# 11558                                          77.321456
# 11559                                          77.226168
# 11560                                          77.073845
# 11561                                          76.888435
#
#        Mean diastolic blood pressure upper 95% uncertainty interval (mmHg)  \
# 3321                                           83.795106
# 3322                                           83.382430
# 3323                                           83.091873
# 3324                                           82.785494
# 3325                                           82.465459
# ...                                                  ...
# 11557                                          79.971426
# 11558                                          80.237050
# 11559                                          80.553494
# 11560                                          80.946841
# 11561                                          81.324055
#
#        Prevalence of raised blood pressure  \
# 3321                              0.242063
# 3322                              0.242517
# 3323                              0.242985
# 3324                              0.243477
# 3325                              0.244013
# ...                                    ...
# 11557                             0.246648
# 11558                             0.246918
# 11559                             0.247142
# 11560                             0.247312
# 11561                             0.247448
#
#        Prevalence of raised blood pressure lower 95% uncertainty interval  \
# 3321                                            0.140102
# 3322                                            0.145429
# 3323                                            0.151062
# 3324                                            0.156043
# 3325                                            0.160331
# ...                                                  ...
# 11557                                           0.205277
# 11558                                           0.202225
# 11559                                           0.198809
# 11560                                           0.194690
# 11561                                           0.189873
#
#        Prevalence of raised blood pressure upper 95% uncertainty interval
# 3321                                            0.361623
# 3322                                            0.355080
# 3323                                            0.348327
# 3324                                            0.342532
# 3325                                            0.337049
# ...                                                  ...
# 11557                                           0.289974
# 11558                                           0.294040
# 11559                                           0.298864
# 11560                                           0.305265
# 11561                                           0.311333
#
# [82 rows x 13 columns]

# %%
## Visualisation
df = Blood_Pressure_Countires_Wise_country_specific
        
    

labels = df['Year']
prev_rbp = df['Prevalence of raised blood pressure']
prev_low_95 = df['Prevalence of raised blood pressure lower 95% uncertainty interval']
prev_high_95 = df['Prevalence of raised blood pressure upper 95% uncertainty interval']
        
title1 = 'Raised Blood Pressure prevelance in (Men followed by Women)' + str(Country_to_look_for)
         
        #high = max(conf)
        #low = min(conf)
        
x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(20,20))
rects1 = ax.bar(x-width/2, prev_rbp, width, label='prev_rbp')
rects2 = ax.bar(x, prev_low_95, width, label='prev_low_95')
rects3 = ax.bar(x+width/2, prev_high_95, width, label='prev_high_95')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

    
    
plt.show()

# %% [markdown]
# ## 3. Diabetes_Countires_Wise

# %%
## Check the List of Countries avaialable

## Columns renaming for Uniformity
Diabetes_Countires_Wise = Diabetes_Countires_Wise.rename(columns={'Country/Region/World': 'Country'})
count_avalaible(Diabetes_Countires_Wise,'Country')
# Out:
# Guinea Bissau | Estonia | Mauritania | Barbados | Sri Lanka | Viet Nam | Samoa |
# Indonesia | Greece | Trinidad and Tobago | Lao PDR | Ireland | Italy | Chile |
# Ethiopia | North Korea | Papua New Guinea | Malaysia | French Polynesia | Greenland | Switzerland |
# Somalia | Cameroon | Cabo Verde | Czech Republic | Kiribati | Yemen | Peru |
# Pakistan | Palau | Turkmenistan | Panama | Tokelau | Saint Vincent and the Grenadines | Qatar |
# Egypt | Paraguay | Latvia | Spain | Angola | Maldives | Mongolia |
# Tunisia | Saint Lucia | Tonga | Brunei Darussalam | Romania | Antigua and Barbuda | Colombia |
# Dominica | Germany | Israel | Grenada | Venezuela | Mexico | Iraq |
# Solomon Islands | Gabon | Uzbekistan | Sierra Leone | Burundi | Nicaragua | Saudi Arabia |
# Bulgaria | Morocco | Comoros | Tuvalu | Botswana | United Arab Emirates | Taiwan |
# Belize | Bahamas | Namibia | Benin | Mozambique | Equatorial Guinea | Armenia |
# Slovakia | Cyprus | China | Ecuador | Libya | Azerbaijan | Guinea |
# Norway | Liberia | Micronesia (Federated States of) | Lithuania | Austria | China (Hong Kong SAR) | Macedonia (TFYR) |
# Eritrea | Australia | Kuwait | Iran | Syrian Arab Republic | Vanuatu | Congo |
# Malta | Tajikistan | Turkey | Dominican Republic | Andorra | Kenya | Haiti |
# South Korea | Cuba | Kyrgyzstan | Myanmar | Sudan | Philippines | Guyana |
# Bolivia | Montenegro | Lebanon | Saint Kitts and Nevis | Belarus | Albania | Swaziland |
# Burkina Faso | Iceland | Guatemala | Bangladesh | Fiji | Croatia | Slovenia |
# Uganda | Djibouti | Niue | Niger | United Kingdom | Zambia | Hungary |
# Bosnia and Herzegovina | Bhutan | American Samoa | Honduras | Ghana | Nigeria | Georgia |
# Bermuda | Jamaica | Afghanistan | United States of America | Brazil | Netherlands | Gambia |
# Costa Rica | Cote d'Ivoire | Poland | Bahrain | Occupied Palestinian Territory | France | Moldova |
# India | Canada | Jordan | Rwanda | Thailand | Timor-Leste | Central African Republic |
# Serbia | Tanzania | Oman | Lesotho | Denmark | Mauritius | Cook Islands |
# Finland | El Salvador | Sweden | South Africa | Belgium | Argentina | Nauru |
# Togo | Zimbabwe | Senegal | Uruguay | Seychelles | Cambodia | Chad |
# Algeria | New Zealand | Suriname | DR Congo | Puerto Rico | Madagascar | Ukraine |
# Japan | Russian Federation | Mali | Sao Tome and Principe | Singapore | Kazakhstan | Malawi |
# Nepal | Portugal | Luxembourg | Marshall Islands |
#
# ##Total No of Countries = 200

# %%
## Analysing the data Structure

Country_to_look_for = 'India'
ylab = "ratio"
xlab = "Year"

filter1 = Diabetes_Countires_Wise['Country'] == Country_to_look_for
Diabetes_Countires_Wise_country_specific = Diabetes_Countires_Wise[filter1]
Diabetes_Countires_Wise_country_specific                 
#Diabetes_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#      Country  ISO    Sex  Year  Age-standardised diabetes prevalence  \
# 2835   India  IND    Men  1980                              0.036589
# 2836   India  IND    Men  1981                              0.038088
# 2837   India  IND    Men  1982                              0.039663
# 2838   India  IND    Men  1983                              0.041308
# 2839   India  IND    Men  1984                              0.043005
# ...      ...  ...    ...   ...                                   ...
# 9865   India  IND  Women  2010                              0.081243
# 9866   India  IND  Women  2011                              0.081729
# 9867   India  IND  Women  2012                              0.082231
# 9868   India  IND  Women  2013                              0.082734
# 9869   India  IND  Women  2014                              0.083259
#
#       Lower 95% uncertainty interval  Upper 95% uncertainty interval
# 2835                        0.012934                        0.078182
# 2836                        0.014617                        0.078115
# 2837                        0.016398                        0.078169
# 2838                        0.018390                        0.078709
# 2839                        0.020178                        0.078566
# ...                              ...                             ...
# 9865                        0.054659                        0.112790
# 9866                        0.053318                        0.115559
# 9867                        0.051335                        0.118902
# 9868                        0.049554                        0.122473
# 9869                        0.047626                        0.127598
#
# [70 rows x 7 columns]

# %%
## Visualisation

df = Diabetes_Countires_Wise_country_specific
        
    

labels = df['Year']
prev_dibates = df['Age-standardised diabetes prevalence']
prev_low_95 = df['Lower 95% uncertainty interval']
prev_high_95 = df['Upper 95% uncertainty interval']
        
title1 = 'Diabetes prevelance in (Men followed by Women) ' + str(Country_to_look_for)
         
        #high = max(conf)
        #low = min(conf)
        
x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(40,20))
rects1 = ax.bar(x-width/2, prev_dibates, width, label='prev_dibates')
rects2 = ax.bar(x, prev_low_95, width, label='prev_low_95')
rects3 = ax.bar(x+width/2, prev_high_95, width, label='prev_high_95')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

    
    
plt.show()

# %% [markdown]
# ## 4. HIV_Countires_Wise

# %%
## Check the List of Countries avaialable

## Columns renaming for Uniformity
HIV_Countires_Wise = HIV_Countires_Wise.rename(columns={'Country Name': 'Country'})
count_avalaible(HIV_Countires_Wise,'Country')
# Out:
# nan | Estonia | Mauritania | Barbados | South Asia (IDA & IBRD) | Sri Lanka | Samoa |
# Indonesia | Curacao | Greece | Lao PDR | Trinidad and Tobago | Ireland | British Virgin Islands |
# Italy | Chile | Upper middle income | Ethiopia | Venezuela, RB | Papua New Guinea | Latin America & Caribbean (excluding high income) |
# Macao SAR, China | Malaysia | French Polynesia | Greenland | Switzerland | East Asia & Pacific | Somalia |
# World | Nigeria | Cameroon | Cabo Verde | Czech Republic | Kiribati | North Macedonia |
# Iran, Islamic Rep. | Peru | Pakistan | Palau | Latin America & the Caribbean (IDA & IBRD countries) | Panama | Turkmenistan |
# Early-demographic dividend | Qatar | Paraguay | Latvia | Slovak Republic | Spain | Angola |
# Maldives | Mongolia | Pacific island small states | Tonga | Tunisia | Brunei Darussalam | Romania |
# Antigua and Barbuda | Colombia | Cayman Islands | Dominica | South Asia | Germany | Caribbean small states |
# Israel | Grenada | Mexico | Iraq | St. Lucia | Northern Mariana Islands | Solomon Islands |
# Gabon | Uzbekistan | Not classified | Euro area | Isle of Man | Burundi | Nicaragua |
# Middle income | Sierra Leone | Saudi Arabia | Bulgaria | Morocco | Hong Kong SAR, China | Comoros |
# Tuvalu | Botswana | Low income | Sub-Saharan Africa (IDA & IBRD countries) | East Asia & Pacific (IDA & IBRD countries) | South Sudan | United Arab Emirates |
# Liechtenstein | Korea, Rep. | Belize | Congo, Dem. Rep. | United States | Namibia | Benin |
# Mozambique | Equatorial Guinea | Sub-Saharan Africa | Armenia | Channel Islands | Cyprus | Guam |
# China | Middle East & North Africa (IDA & IBRD countries) | Ecuador | Libya | St. Vincent and the Grenadines | Azerbaijan | Guinea |
# Norway | West Bank and Gaza | Liberia | Lithuania | Austria | Pre-demographic dividend | Latin America & Caribbean |
# Other small states | Eritrea | Australia | Kuwait | Vanuatu | Syrian Arab Republic | Malta |
# Tajikistan | Turkey | Gibraltar | Dominican Republic | OECD members | Andorra | European Union |
# Kenya | Haiti | Cuba | Kosovo | Myanmar | Sudan | Philippines |
# Guyana | Bolivia | Montenegro | Lebanon | Europe & Central Asia (excluding high income) | San Marino | Belarus |
# Albania | Virgin Islands (U.S.) | Eswatini | Burkina Faso | Turks and Caicos Islands | Iceland | Europe & Central Asia |
# Guatemala | Bangladesh | Fiji | Croatia | Slovenia | Uganda | Djibouti |
# St. Kitts and Nevis | Niger | United Kingdom | Guinea-Bissau | Zambia | Hungary | Bosnia and Herzegovina |
# Bhutan | American Samoa | Gambia, The | Arab World | Ghana | Egypt, Arab Rep. | Georgia |
# High income | Honduras | Bermuda | Jamaica | Afghanistan | Brazil | Netherlands |
# Costa Rica | Faroe Islands | Congo, Rep. | Monaco | Cote d'Ivoire | Poland | Bahrain |
# Sint Maarten (Dutch part) | France | Moldova | India | Canada | Jordan | Korea, Dem. People’s Rep. |
# Kyrgyz Republic | Micronesia, Fed. Sts. | Central African Republic | North America | Rwanda | Serbia | Tanzania |
# Thailand | Oman | Timor-Leste | Lesotho | Denmark | Mauritius | Middle East & North Africa (excluding high income) |
# Finland | El Salvador | Lower middle income | Middle East & North Africa | Sweden | South Africa | Belgium |
# Argentina | Nauru | Togo | Zimbabwe | Senegal | East Asia & Pacific (excluding high income) | Sub-Saharan Africa (excluding high income) |
# Uruguay | Low & middle income | Heavily indebted poor countries (HIPC) | Europe & Central Asia (IDA & IBRD countries) | Seychelles | Cambodia | Bahamas, The |
# Post-demographic dividend | Chad | Algeria | New Zealand | Suriname | Late-demographic dividend | Fragile and conflict affected situations |
# Puerto Rico | Aruba | Madagascar | Ukraine | Japan | Yemen, Rep. | Central Europe and the Baltics |
# St. Martin (French part) | Least developed countries: UN classification | New Caledonia | Mali | Russian Federation | Sao Tome and Principe | Singapore |
# Kazakhstan | Malawi | Nepal | Portugal | Luxembourg | Marshall Islands | Vietnam |
# Small states |
#
# ##Total No of Countries = 260

# %%
HIV_Countires_Wise = HIV_Countires_Wise.dropna()
## Analysing the data Structure

Country_to_look_for = 'Vietnam'
ylab = "Population"
xlab = "Countries"

filter1 = HIV_Countires_Wise['Country'] == Country_to_look_for
HIV_Countires_Wise_country_specific = HIV_Countires_Wise[filter1]
#HIV_Countires_Wise_country_specific                
HIV_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#                            Series Name  Series Code             Country  \
# 0    Adults (ages 15+) living with HIV  SH.DYN.AIDS         Afghanistan
# 1    Adults (ages 15+) living with HIV  SH.DYN.AIDS             Albania
# 2    Adults (ages 15+) living with HIV  SH.DYN.AIDS             Algeria
# 3    Adults (ages 15+) living with HIV  SH.DYN.AIDS      American Samoa
# 4    Adults (ages 15+) living with HIV  SH.DYN.AIDS             Andorra
# ..                                 ...          ...                 ...
# 254  Adults (ages 15+) living with HIV  SH.DYN.AIDS  West Bank and Gaza
# 255  Adults (ages 15+) living with HIV  SH.DYN.AIDS               World
# 256  Adults (ages 15+) living with HIV  SH.DYN.AIDS         Yemen, Rep.
# 257  Adults (ages 15+) living with HIV  SH.DYN.AIDS              Zambia
# 258  Adults (ages 15+) living with HIV  SH.DYN.AIDS            Zimbabwe
#
#     Country Code 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]
# 0            AFG          6500          6900            ..
# 1            ALB            ..            ..            ..
# 2            DZA         14000         15000            ..
# 3            ASM            ..            ..            ..
# 4            AND            ..            ..            ..
# ..           ...           ...           ...           ...
# 254          PSE            ..            ..            ..
# 255          WLD      35400000      36200000            ..
# 256          YEM          9800         10000            ..
# 257          ZMB       1100000       1200000            ..
# 258          ZWE       1200000       1200000            ..
#
# [259 rows x 7 columns]

# %%
## Visualisation

df = HIV_Countires_Wise
        
    

labels = df['Country Code']
prev_2017 = df['2017 [YR2017]']
prev_2018 = df['2018 [YR2018]']
prev_2019 = df['2019 [YR2019]']
        
title1 = 'HIV prevelance in All Countries'
         
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .80  # the width of the bars
fig, ax = plt.subplots(figsize=(60,60))
rects1 = ax.bar(x-width/2, prev_2017, width, label='prev_2017')
rects2 = ax.bar(x, prev_2018, width, label='prev_2018')
rects3 = ax.bar(x+width/2, prev_2019, width, label='prev_2019')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

    
    
plt.show()

# %% [markdown]
# ## 5. Tuber_Culosis_Countires_Wise

# %%
## Check the List of Countries avaialable

## Columns renaming for Uniformity
Tuber_Culosis_Countires_Wise = Tuber_Culosis_Countires_Wise.rename(columns={'country': 'Country'})
count_avalaible(Tuber_Culosis_Countires_Wise,'Country')
# Out:
# Estonia | Mauritania | Barbados | Bolivia (Plurinational State of) | Sri Lanka | Samoa | Viet Nam |
# Indonesia | Greece | Trinidad and Tobago | Ireland | British Virgin Islands | Republic of Moldova | Italy |
# Chile | Ethiopia | Papua New Guinea | Malaysia | French Polynesia | Greenland | Switzerland |
# Somalia | Côte d'Ivoire | Cameroon | Cabo Verde | Kiribati | North Macedonia | Yemen |
# Peru | Pakistan | Palau | Turkmenistan | Panama | Tokelau | Saint Vincent and the Grenadines |
# Qatar | Egypt | Paraguay | Latvia | Spain | Serbia & Montenegro | Iran (Islamic Republic of) |
# Angola | Maldives | Mongolia | Tunisia | Saint Lucia | Tonga | Brunei Darussalam |
# Czechia | Antigua and Barbuda | Romania | Colombia | Cayman Islands | Dominica | Germany |
# Israel | Venezuela (Bolivarian Republic of) | Grenada | Mexico | Iraq | Northern Mariana Islands | Netherlands Antilles |
# Gabon | Solomon Islands | Uzbekistan | Democratic People's Republic of Korea | Burundi | Curaçao | Nicaragua |
# Sierra Leone | Saudi Arabia | Bulgaria | Morocco | Comoros | Tuvalu | Botswana |
# South Sudan | United Arab Emirates | Bahamas | Belize | Namibia | Benin | Mozambique |
# Equatorial Guinea | Armenia | Slovakia | Cyprus | Guam | China | Ecuador |
# Libya | Azerbaijan | Guinea | Norway | Liberia | Micronesia (Federated States of) | Lithuania |
# Austria | Eritrea | Australia | Kuwait | United Republic of Tanzania | Syrian Arab Republic | Vanuatu |
# Congo | Malta | Tajikistan | Turkey | Dominican Republic | Andorra | Kenya |
# Haiti | Cuba | Kyrgyzstan | Myanmar | Sudan | Philippines | Guyana |
# Montserrat | Montenegro | Lebanon | Saint Kitts and Nevis | Republic of Korea | San Marino | Belarus |
# Albania | United Kingdom of Great Britain and Northern Ireland | Eswatini | Burkina Faso | Turks and Caicos Islands | Iceland | Guatemala |
# Bangladesh | Fiji | Croatia | Slovenia | Uganda | Djibouti | Niue |
# Democratic Republic of the Congo | Niger | Guinea-Bissau | Zambia | Hungary | Bosnia and Herzegovina | Bhutan |
# American Samoa | Honduras | Ghana | Nigeria | Georgia | Bermuda | Jamaica |
# Afghanistan | United States of America | Brazil | Netherlands | Gambia | occupied Palestinian territory, including east Jerusalem | Costa Rica |
# China, Macao SAR | Wallis and Futuna Islands | Monaco | Poland | Bahrain | Sint Maarten (Dutch part) | France |
# India | Canada | Jordan | Rwanda | Thailand | Timor-Leste | Central African Republic |
# Serbia | Oman | Lesotho | Denmark | Mauritius | Cook Islands | Finland |
# El Salvador | Sweden | South Africa | Belgium | Anguilla | Argentina | Nauru |
# Togo | Zimbabwe | Senegal | Uruguay | Seychelles | Cambodia | Chad |
# Algeria | China, Hong Kong SAR | New Zealand | Suriname | Puerto Rico | Aruba | Lao People's Democratic Republic |
# Madagascar | Japan | Ukraine | New Caledonia | Russian Federation | Mali | Sao Tome and Principe |
# Singapore | Kazakhstan | Malawi | Nepal | Portugal | Luxembourg | Marshall Islands |
#
#
# ##Total No of Countries = 217

# %%
## Analysing the data Structure


Country_to_look_for = 'India'
ylab = "Affected_Population"
xlab = "Year"


filter1 = Tuber_Culosis_Countires_Wise['Country'] == Country_to_look_for
Tuber_Culosis_Countires_Wise_country_specific = Tuber_Culosis_Countires_Wise[filter1]
Tuber_Culosis_Countires_Wise_country_specific              
#Tuber_Culosis_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#      Country iso2 iso3  iso_numeric g_whoregion  year    new_sp    new_sn  \
# 3480   India   IN  IND          356         SEA  1980       NaN       NaN
# 3481   India   IN  IND          356         SEA  1981       NaN       NaN
# 3482   India   IN  IND          356         SEA  1982       NaN       NaN
# 3483   India   IN  IND          356         SEA  1983       NaN       NaN
# 3484   India   IN  IND          356         SEA  1984       NaN       NaN
# 3485   India   IN  IND          356         SEA  1985       NaN       NaN
# 3486   India   IN  IND          356         SEA  1986       NaN       NaN
# 3487   India   IN  IND          356         SEA  1987       NaN       NaN
# 3488   India   IN  IND          356         SEA  1988       NaN       NaN
# 3489   India   IN  IND          356         SEA  1989       NaN       NaN
# 3490   India   IN  IND          356         SEA  1990       NaN       NaN
# 3491   India   IN  IND          356         SEA  1991       NaN       NaN
# 3492   India   IN  IND          356         SEA  1992       NaN       NaN
# 3493   India   IN  IND          356         SEA  1993  225256.0       NaN
# 3494   India   IN  IND          356         SEA  1994  226543.0       NaN
# 3495   India   IN  IND          356         SEA  1995  264515.0  880589.0
# 3496   India   IN  IND          356         SEA  1996  290953.0  932998.0
# 3497   India   IN  IND          356         SEA  1997  274877.0    7089.0
# 3498   India   IN  IND          356         SEA  1998  278275.0  770765.0
# 3499   India   IN  IND          356         SEA  1999  345150.0  777783.0
# 3500   India   IN  IND          356         SEA  2000  349374.0  650345.0
# 3501   India   IN  IND          356         SEA  2001  384827.0  554437.0
# 3502   India   IN  IND          356         SEA  2002  395833.0  506249.0
# 3503   India   IN  IND          356         SEA  2003  433564.0  459424.0
# 3504   India   IN  IND          356         SEA  2004  489195.0  432364.0
# 3505   India   IN  IND          356         SEA  2005  508890.0  399066.0
# 3506   India   IN  IND          356         SEA  2006  553851.0  400680.0
# 3507   India   IN  IND          356         SEA  2007  592587.0  398862.0
# 3508   India   IN  IND          356         SEA  2008  615977.0  390356.0
# 3509   India   IN  IND          356         SEA  2009  624617.0  384113.0
# 3510   India   IN  IND          356         SEA  2010  630165.0  366381.0
# 3511   India   IN  IND          356         SEA  2011  642321.0  340203.0
# 3512   India   IN  IND          356         SEA  2012  629589.0  317616.0
# 3513   India   IN  IND          356         SEA  2013       NaN       NaN
# 3514   India   IN  IND          356         SEA  2014       NaN       NaN
# 3515   India   IN  IND          356         SEA  2015       NaN       NaN
# 3516   India   IN  IND          356         SEA  2016       NaN       NaN
# 3517   India   IN  IND          356         SEA  2017       NaN       NaN
# 3518   India   IN  IND          356         SEA  2018       NaN       NaN
#
#         new_su    new_ep  ...  hiv_cpt  hiv_art  hiv_tbscr    hiv_reg  \
# 3480       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3481       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3482       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3483       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3484       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3485       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3486       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3487       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3488       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3489       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3490       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3491       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3492       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3493       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3494       NaN       NaN  ...      NaN      NaN        NaN        NaN
# 3495       0.0   68979.0  ...      NaN      NaN        NaN        NaN
# 3496       NaN   75822.0  ...      NaN      NaN        NaN        NaN
# 3497  787338.0   66991.0  ...      NaN      NaN        NaN        NaN
# 3498       NaN   73276.0  ...      NaN      NaN        NaN        NaN
# 3499       0.0   88128.0  ...      NaN      NaN        NaN        NaN
# 3500       0.0   98006.0  ...      NaN      NaN        NaN        NaN
# 3501       0.0  113177.0  ...      NaN      NaN        NaN        NaN
# 3502       0.0  120105.0  ...      NaN      NaN        NaN        NaN
# 3503       0.0  132253.0  ...      NaN      NaN        NaN        NaN
# 3504       0.0  151386.0  ...      NaN      NaN        NaN        NaN
# 3505       0.0  171838.0  ...      NaN      NaN    10597.0   135312.0
# 3506       0.0  183203.0  ...      NaN      NaN    25055.0   196815.0
# 3507       0.0  206840.0  ...    724.0    162.0    50586.0   277760.0
# 3508       0.0  219946.0  ...   4098.0   2487.0   275875.0   512596.0
# 3509       NaN  233026.0  ...  32498.0  18188.0   280903.0   280903.0
# 3510       NaN  231121.0  ...  37327.0  23641.0   199732.0   199732.0
# 3511       NaN  226965.0  ...  40583.0  26165.0   386081.0        NaN
# 3512       NaN  234029.0  ...  40537.0  25790.0  1324386.0  1324386.0
# 3513       NaN  226557.0  ...  41827.0  39821.0  1063644.0  1063644.0
# 3514       NaN  275502.0  ...  41066.0  39800.0  1114394.0  1114394.0
# 3515       NaN  298831.0  ...      NaN      NaN        NaN        NaN
# 3516       NaN  281162.0  ...      NaN      NaN        NaN        NaN
# 3517       NaN  276786.0  ...      NaN      NaN        NaN        NaN
# 3518       NaN  380904.0  ...      NaN      NaN        NaN        NaN
#
#       hiv_ipt  hiv_reg_new  hiv_ipt_reg_all  hiv_reg_all  hiv_tbdetect  \
# 3480      NaN          NaN              NaN          NaN           NaN
# 3481      NaN          NaN              NaN          NaN           NaN
# 3482      NaN          NaN              NaN          NaN           NaN
# 3483      NaN          NaN              NaN          NaN           NaN
# 3484      NaN          NaN              NaN          NaN           NaN
# 3485      NaN          NaN              NaN          NaN           NaN
# 3486      NaN          NaN              NaN          NaN           NaN
# 3487      NaN          NaN              NaN          NaN           NaN
# 3488      NaN          NaN              NaN          NaN           NaN
# 3489      NaN          NaN              NaN          NaN           NaN
# 3490      NaN          NaN              NaN          NaN           NaN
# 3491      NaN          NaN              NaN          NaN           NaN
# 3492      NaN          NaN              NaN          NaN           NaN
# 3493      NaN          NaN              NaN          NaN           NaN
# 3494      NaN          NaN              NaN          NaN           NaN
# 3495      NaN          NaN              NaN          NaN           NaN
# 3496      NaN          NaN              NaN          NaN           NaN
# 3497      NaN          NaN              NaN          NaN           NaN
# 3498      NaN          NaN              NaN          NaN           NaN
# 3499      NaN          NaN              NaN          NaN           NaN
# 3500      NaN          NaN              NaN          NaN           NaN
# 3501      NaN          NaN              NaN          NaN           NaN
# 3502      NaN          NaN              NaN          NaN           NaN
# 3503      NaN          NaN              NaN          NaN           NaN
# 3504      NaN          NaN              NaN          NaN           NaN
# 3505      NaN          NaN              NaN          NaN           NaN
# 3506      NaN          NaN              NaN          NaN           NaN
# 3507      NaN          NaN              NaN          NaN           NaN
# 3508      0.0          NaN              NaN          NaN           NaN
# 3509      NaN          NaN              NaN          NaN           NaN
# 3510      NaN          NaN              NaN          NaN           NaN
# 3511      NaN     274560.0              NaN          NaN           NaN
# 3512      NaN          NaN              NaN          NaN           NaN
# 3513      NaN          NaN              NaN          NaN       24914.0
# 3514      NaN          NaN              NaN          NaN        5558.0
# 3515      NaN          NaN              NaN          NaN       21065.0
# 3516   8135.0     174125.0              NaN          NaN       21032.0
# 3517  18162.0     173174.0              NaN          NaN       19403.0
# 3518  29214.0     175361.0         495298.0    1312561.0       29766.0
#
#       hiv_reg_new2
# 3480           NaN
# 3481           NaN
# 3482           NaN
# 3483           NaN
# 3484           NaN
# 3485           NaN
# 3486           NaN
# 3487           NaN
# 3488           NaN
# 3489           NaN
# 3490           NaN
# 3491           NaN
# 3492           NaN
# 3493           NaN
# 3494           NaN
# 3495           NaN
# 3496           NaN
# 3497           NaN
# 3498           NaN
# 3499           NaN
# 3500           NaN
# 3501           NaN
# 3502           NaN
# 3503           NaN
# 3504           NaN
# 3505           NaN
# 3506           NaN
# 3507           NaN
# 3508           NaN
# 3509           NaN
# 3510           NaN
# 3511           NaN
# 3512           NaN
# 3513     1063644.0
# 3514      178124.0
# 3515      178470.0
# 3516      174125.0
# 3517      173174.0
# 3518      175361.0
#
# [39 rows x 165 columns]

# %%
## Visualisation
df = Tuber_Culosis_Countires_Wise_country_specific
            

labels = df['year']
prev_c_newinc = df['c_newinc']
prev_hiv_tbscr = df['hiv_tbscr']
prev_hiv_reg = df['hiv_reg']
        
title1 = 'TB prevelance in ' + str(Country_to_look_for)
         
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(40,30))
rects1 = ax.bar(x-width/2, prev_c_newinc, width, label='prev_c_newinc')
rects2 = ax.bar(x, prev_hiv_tbscr, width, label='prev_hiv_tbscr')
rects3 = ax.bar(x+width/2, prev_hiv_reg, width, label='prev_hiv_reg')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

    
    
plt.show()

# %% [markdown]
# ## 6. Population_Data_Countires_Wise

# %%
## Check the List of Countries avaialable

## Columns renaming for Uniformity
Population_Data_Countires_Wise = Population_Data_Countires_Wise.rename(columns={'Location': 'Country'})
count_avalaible(Population_Data_Countires_Wise,'Country')
# Out:
# Estonia | Bolivia (Plurinational State of) | Samoa | Indonesia | LLDC: Asia | Southern African Development Community (SADC) | Belt-Road Initiative (BRI) |
# UNICEF Regions: North America | Italy | Ethiopia | Eurasian Economic Community (Eurasec) | WHO: Eastern Mediterranean Region (EMRO) | ESCAP: ADB Group A (Concessional assistance only) | ESCWA: Maghreb countries |
# Eastern and South-Eastern Asia | Peru | Saint Vincent and the Grenadines | Paraguay | Organization of the Islamic Conference (OIC) | Saint Lucia | Tonga |
# UNFPA: Asia and the Pacific (AP) | Asia-Pacific Group | Latin American Integration Association (ALADI) | Czechia | Eastern Asia | UNICEF Regions: East Asia and Pacific | Germany |
# ESCAP: high income | Solomon Islands | South Asian Association for Regional Cooperation (SAARC) | Europe and Northern America | Nicaragua | Eastern European Group | Saudi Arabia |
# North American Free Trade Agreement (NAFTA) | Bulgaria | WB region: Sub-Saharan Africa (excluding high income) | World Bank Regional Groups (developing only) | WHO: African region (AFRO) | UNITED NATIONS Regional Groups of Member States | Bahamas |
# Guam | Micronesia (Fed. States of) | Ecuador | WHO: Western Pacific region (WPRO) | WHO: Americas (AMRO) | Lithuania | UNICEF Programme Regions: Latin America and Caribbean (LACRO) |
# Réunion | Vanuatu | Tajikistan | LLDC: Africa | Greater Arab Free Trade Area (GAFTA) | Haiti | Economic Community of Central African States (ECCAS) |
# Eastern Africa | Less developed: Africa | United Nations Economic Commission for Africa (UN-ECA) | Least developed: Latin America and the Caribbean | Netherlands (and dependencies) | Guyana | Montenegro |
# Commonwealth: Pacific | ECE: North America-2 | Martinique | Iceland | Guatemala | Bangladesh | WB region: South Asia (excluding high income) |
# Croatia | Slovenia | Democratic Republic of the Congo | Zambia | Honduras | Caribbean Community and Common Market (CARICOM) | WB region: Middle East and North Africa (excluding high income) |
# UNICEF Regions: West and Central Africa | ESCAP: lower middle HDI | ECE: UNECE-52 | South-Eastern Asia | China, Macao SAR | Commonwealth: Asia | SIDS Atlantic, and Indian Ocean, Mediterranean and South China Sea (AIMS) |
# Bolivarian Alliance for the Americas (ALBA) | UNICEF Regions: Eastern and Southern Africa | France | Group of 77 (G77) | Timor-Leste | France (and dependencies) | Serbia |
# Oman | UNICEF Regions: Eastern Europe and Central Asia | Lesotho | Denmark | Mauritius | El Salvador | UNFPA: Latin America and the Caribbean (LAC) |
# ESCWA: Gulf Cooperation Council countries | ECLAC: Latin America | Land-locked Countries (Others) | Commonwealth: Africa | Algeria | ESCAP: low HDI | African Union |
# Low-income countries | Lao People's Democratic Republic | Eastern Europe | Japan | New Caledonia | Mali | Sao Tome and Principe |
# Singapore | UNFPA Regions | Europe (48) | Sri Lanka | Viet Nam | ESCAP: upper middle HDI | African, Caribbean and Pacific (ACP) Group of States |
# Chile | Papua New Guinea | UNICEF Regions: Middle East and North Africa | Malaysia | Dem. People's Republic of Korea | Oceania | Switzerland |
# UNFPA: Eastern Europe and Central Asia (EECA) | Somalia | Cabo Verde | Kiribati | No income group available | UNFPA: West and Central Africa (WCA) | Yemen |
# Western Sahara | Panama | Western Africa | Less developed regions, excluding China | Latvia | Northern Africa | Australia/New Zealand |
# Iran (Islamic Republic of) | UNICEF Programme Regions: Latin America | Melanesia | Tunisia | Brunei Darussalam | ESCWA: Arab countries | Romania |
# Colombia | European Community (EC: 12) | Israel | Mexico | UNICEF Regions: Latin America and Caribbean | Organization for Security and Co-operation in Europe (OSCE) | UNICEF PROGRAMME REGIONS |
# Curaçao | China, Taiwan Province of China | Western European and Others Group (WEOG) | United Nations Economic and Social Commission for Asia and the Pacific (UN-ESCAP) Regions | UNICEF Programme Regions: Eastern Caribbean | United Arab Emirates | Belize |
# African Union: Northern Africa | Namibia | Mozambique | UNICEF Programme Regions: West and Central Africa (WCARO) | League of Arab States (LAS, informal name: Arab League) | China | ECLAC: The Caribbean |
# Libya | Azerbaijan | Guinea | Countries with Access to the Sea: Oceania | African Union: Western Africa | Caribbean | Southern Africa |
# United Republic of Tanzania | Kuwait | Syrian Arab Republic | United Nations Economic Commission for Latin America and the Caribbean (UN-ECLAC) | ESCAP: Least Developed Countries (LDCs) | LLDC: Europe | Republic of Korea |
# ESCAP: ADB Group C (Regular OCR only) | ESCAP: HDI groups | Less developed regions, excluding least developed countries | Burkina Faso | Northern Europe | Countries with Access to the Sea: Africa | Niger |
# United Kingdom | Commonwealth: Caribbean and Americas | Nigeria | WHO Regions | Small Island Developing States (SIDS) | Ghana | United States of America |
# Gambia | Costa Rica | UNFPA: East and Southern Africa (ESA) | More developed: Asia | India | Canada | Rwanda |
# ESCAP: Pacific island dev. econ. | Central African Republic | WHO: South-East Asia region (SEARO) | Countries with Access to the Sea: Northern America | Finland | Senegal | Organization of Petroleum Exporting countries (OPEC) |
# China, Hong Kong SAR | African Union: Eastern Africa | BRICS | More developed: Oceania | Malawi | Nepal | LLDC: Latin America |
# Luxembourg | BRIC | Greece | Trinidad and Tobago | Republic of Moldova | Asia | Least developed: Africa |
# South America | UNICEF Programme Regions: Middle East and North Africa (MENARO) | World | Cameroon | United Nations Member States | ESCWA: Arab least developed countries | UNICEF Regions: South Asia |
# ESCAP: lower middle income | More developed: Northern America | Turkmenistan | Group of Twenty (G20) - member states | Egypt | ESCAP: ECO | Commonwealth: Europe |
# Spain | Less developed: Oceania | Angola | UNICEF Programme Regions: East Asia and Pacific (EAPRO) | Maldives | Micronesia | Grenada |
# Gabon | Africa | State of Palestine | Uzbekistan | Central and Southern Asia | Morocco | Comoros |
# ESCAP region: North and Central Asia | Group of Eight (G8) | West African Economic and Monetary Union (UEMOA) | Belt-Road Initiative: Asia | Benin | Equatorial Guinea | Armenia |
# Channel Islands | ESCAP: other Asia-Pacific countries/areas | Slovakia | Cyprus | African Group | ESCAP: Landlocked countries (LLDCs) | Economic Cooperation Organization (ECO) |
# WB region: East Asia and Pacific (excluding high income) | Countries with Access to the Sea: Europe | Less developed: Latin America and the Caribbean | Austria | ESCAP: WB Upper middle income econ. | Economic Community of West African States (ECOWAS) | Northern America |
# Australia | ESCAP: WB Lower middle income econ. | Malta | Turkey | ESCAP: low income | New EU member states (joined since 2004) | Kenya |
# Kyrgyzstan | Myanmar | Sudan | UNICEF Regions: Europe and Central Asia | WHO: European Region (EURO) | ESCWA: member countries | Lebanon |
# China (and dependencies) | Albania | Eswatini | Latin American and Caribbean Group (GRULAC) | Hungary | Bosnia and Herzegovina | Afghanistan |
# Polynesia | Brazil | Least developed countries | Belt-Road Initiative: Europe | Commonwealth of Independent States (CIS) | Less developed regions | Central America |
# European Free Trade Agreement (EFTA) | Countries with Access to the Sea: Latin America and the Caribbean | ESCAP: WB Low income econ. | United Kingdom (and dependencies) | Mayotte | Belt-Road Initiative: Pacific | ESCAP: ADB Developing member countries (DMCs) |
# Middle Africa | Southern Common Market (MERCOSUR) | South Africa | Belgium | Togo | Zimbabwe | ESCAP: SAARC |
# Western Asia | Lower-middle-income countries | North Atlantic Treaty Organization (NATO) | Cambodia | Chad | Organisation for Economic Co-operation and Development (OECD) | Suriname |
# Aruba | Madagascar | ESCAP region: Pacific | Ukraine | ESCAP: income groups | Russian Federation | Kazakhstan |
# SIDS Caribbean | Portugal | French Guiana | Mauritania | Barbados | Ireland | Non-Self-Governing Territories |
# UN-ECE: member countries | Andean Community | ESCAP region: South and South-West Asia | French Polynesia | High-income countries | More developed regions | Côte d'Ivoire |
# North Macedonia | Land-locked Countries | ESCWA: Mashreq countries | European Union (EU: 28) | New Zealand (and dependencies) | Pakistan | Qatar |
# UNICEF Regions: Sub-Saharan Africa | Denmark (and dependencies) | Mongolia | Less developed: Asia | Antigua and Barbuda | Upper-middle-income countries | More developed: Europe |
# Commonwealth of Nations | Venezuela (Bolivarian Republic of) | Group of Seven (G7) | Iraq | Sierra Leone | Burundi | ESCAP region: East and North-East Asia |
# ESCAP region: South-East Asia | Belt-Road Initiative: Africa | Botswana | Northern Africa and Western Asia | South Sudan | ESCAP: WB High income econ. | African Union: Southern Africa |
# Central European Free Trade Agreement (CEFTA) | European Union (EU: 15) | ESCAP: ASEAN | Sub-Saharan Africa | ESCAP: ADB Group B (OCR blend) | Norway | ESCAP: WB income groups |
# Latin America and the Caribbean | Liberia | WB region: Europe and Central Asia (excluding high income) | Middle-income countries | UNICEF Programme Regions: South Asia (ROSA) | Eritrea | Congo |
# Dominican Republic | Cuba | Philippines | Belt-Road Initiative: Latin America and the Caribbean | UNICEF Programme Regions: Eastern and Southern Africa (ESARO) | Black Sea Economic Cooperation (BSEC) | Belarus |
# Europe | Asia-Pacific Economic Cooperation (APEC) | Fiji | Uganda | Djibouti | SIDS Pacific | African Union: Central Africa |
# Guinea-Bissau | United States of America (and dependencies) | Bhutan | Georgia | Jamaica | United States Virgin Islands | Netherlands |
# Organization of American States (OAS) | ESCAP: Central Asia | Central Asia | Poland | Bahrain | Gulf Cooperation Council (GCC) | Shanghai Cooperation Organization (SCO) |
# ESCAP: upper middle income | Jordan | Thailand | UNICEF Programme Regions: Europe and Central Asia (CEECIS) | Sweden | Argentina | Land-locked Developing Countries (LLDC) |
# UNICEF REGIONS | East African Community (EAC) | Southern Europe | Southern Asia | ESCAP: high HDI | Uruguay | WB region: Latin America and Caribbean (excluding high income) |
# Countries with Access to the Sea | Oceania (excluding Australia and New Zealand) | Seychelles | Least developed: Oceania | Countries with Access to the Sea: Asia | Least developed: Asia | New Zealand |
# UNICEF Regions: Western Europe | Association of Southeast Asian Nations (ASEAN) | Puerto Rico | Guadeloupe | Western Europe | UNFPA: Arab States (AS) |
#
# ##Total No of Countries = 440

# %%
## Analysing the data Structure
Country_to_look_for = 'India'
Year_to_look_for = 2019
ylab = "Population"
xlab = "Year"

filter1 = Population_Data_Countires_Wise['Country'] == Country_to_look_for
Population_Data_Countires_Wise_country_specific = Population_Data_Countires_Wise[filter1]
filter2 = Population_Data_Countires_Wise_country_specific['Time'] == Year_to_look_for
Population_Data_Countires_Wise_country_specific = Population_Data_Countires_Wise_country_specific[filter2]
Population_Data_Countires_Wise_country_specific
#Population_Data_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#          LocID Country  VarID Variant  Time  MidPeriod  AgeGrp  AgeGrpStart  \
# 1420969    356   India      2  Medium  2019     2019.5       0            0
# 1420970    356   India      2  Medium  2019     2019.5       1            1
# 1420971    356   India      2  Medium  2019     2019.5       2            2
# 1420972    356   India      2  Medium  2019     2019.5       3            3
# 1420973    356   India      2  Medium  2019     2019.5       4            4
# ...        ...     ...    ...     ...   ...        ...     ...          ...
# 1421065    356   India      2  Medium  2019     2019.5      96           96
# 1421066    356   India      2  Medium  2019     2019.5      97           97
# 1421067    356   India      2  Medium  2019     2019.5      98           98
# 1421068    356   India      2  Medium  2019     2019.5      99           99
# 1421069    356   India      2  Medium  2019     2019.5     100          100
#
#          AgeGrpSpan    PopMale  PopFemale   PopTotal
# 1420969           1  12518.937  11385.787  23904.724
# 1420970           1  12303.679  11187.267  23490.946
# 1420971           1  12179.091  11070.664  23249.755
# 1420972           1  12133.716  11025.350  23159.066
# 1420973           1  12049.429  10927.902  22977.331
# ...             ...        ...        ...        ...
# 1421065           1     27.444     37.908     65.352
# 1421066           1     20.203     28.635     48.838
# 1421067           1     12.618     19.099     31.717
# 1421068           1      7.794     12.509     20.303
# 1421069          -1     15.806     28.978     44.784
#
# [101 rows x 12 columns]

# %%
## Visualisation

df = Population_Data_Countires_Wise_country_specific
            

labels = df['AgeGrp']
prev_PopMale = df['PopMale']
prev_PopFemale = df['PopFemale']
prev_PopTotal = df['PopTotal']
        
title1 = 'Population in ' + str(Country_to_look_for) + ' and year = ' + str(Year_to_look_for)
         
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(40,30))
rects1 = ax.bar(x-width/2, prev_PopMale, width, label='PopMale')
rects2 = ax.bar(x, prev_PopFemale, width, label='PopFemale')
rects3 = ax.bar(x+width/2, prev_PopTotal, width, label='PopTotal')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

    
    
plt.show()

# %% [markdown]
# ## 7. Medical_Expending_Countires_Wise

# %%
## Check the List of Countries avaialable

## Columns renaming for Uniformity
Medical_Expending_Countires_Wise = Medical_Expending_Countires_Wise.rename(columns={'Country Name': 'Country'})
count_avalaible(Medical_Expending_Countires_Wise,'Country')
# Out:
# Estonia | Sri Lanka | Barbados | Mauritania | South Asia (IDA & IBRD) | Samoa | Indonesia |
# IDA & IBRD total | Curacao | Greece | Lao PDR | Trinidad and Tobago | Ireland | British Virgin Islands |
# Italy | Chile | Upper middle income | Ethiopia | Venezuela, RB | Papua New Guinea | Latin America & Caribbean (excluding high income) |
# Macao SAR, China | Malaysia | French Polynesia | Greenland | Switzerland | East Asia & Pacific | Somalia |
# World | Nigeria | Cameroon | Cabo Verde | Czech Republic | Kiribati | North Macedonia |
# Iran, Islamic Rep. | Peru | Pakistan | Palau | Turkmenistan | Panama | Latin America & the Caribbean (IDA & IBRD countries) |
# Early-demographic dividend | Qatar | Paraguay | Latvia | Spain | Slovak Republic | IDA total |
# Angola | Maldives | Mongolia | Pacific island small states | Tonga | Tunisia | Brunei Darussalam |
# IBRD only | IDA blend | Romania | Antigua and Barbuda | Colombia | Cayman Islands | Dominica |
# South Asia | Germany | Caribbean small states | Israel | Grenada | Mexico | Iraq |
# St. Lucia | Northern Mariana Islands | Solomon Islands | Gabon | Uzbekistan | Not classified | Euro area |
# Isle of Man | Burundi | Nicaragua | Middle income | Sierra Leone | Saudi Arabia | IDA only |
# Bulgaria | Morocco | Hong Kong SAR, China | Comoros | Tuvalu | Botswana | Low income |
# Sub-Saharan Africa (IDA & IBRD countries) | East Asia & Pacific (IDA & IBRD countries) | South Sudan | United Arab Emirates | Liechtenstein | Korea, Rep. | Belize |
# Congo, Dem. Rep. | United States | Namibia | Benin | Mozambique | Equatorial Guinea | Sub-Saharan Africa |
# Armenia | Channel Islands | Cyprus | Guam | China | Middle East & North Africa (IDA & IBRD countries) | Ecuador |
# Libya | West Bank and Gaza | Azerbaijan | Guinea | Norway | St. Vincent and the Grenadines | Liberia |
# Lithuania | Austria | Pre-demographic dividend | Latin America & Caribbean | Other small states | Eritrea | Australia |
# Kuwait | Vanuatu | Syrian Arab Republic | Malta | Tajikistan | Turkey | Gibraltar |
# Dominican Republic | OECD members | Andorra | European Union | Kenya | Haiti | Cuba |
# Myanmar | Sudan | Kosovo | Philippines | Guyana | Bolivia | Montenegro |
# Lebanon | Europe & Central Asia (excluding high income) | San Marino | Belarus | Albania | Virgin Islands (U.S.) | Eswatini |
# Burkina Faso | Turks and Caicos Islands | Iceland | Europe & Central Asia | Guatemala | Bangladesh | Fiji |
# Croatia | Slovenia | Uganda | Djibouti | St. Kitts and Nevis | Niger | United Kingdom |
# Guinea-Bissau | Zambia | Hungary | Bosnia and Herzegovina | Bhutan | American Samoa | Gambia, The |
# Arab World | Ghana | Egypt, Arab Rep. | Georgia | High income | Honduras | Bermuda |
# Jamaica | Afghanistan | Brazil | Netherlands | Costa Rica | Faroe Islands | Congo, Rep. |
# Monaco | Cote d'Ivoire | Poland | Bahrain | Sint Maarten (Dutch part) | France | Moldova |
# India | Canada | Jordan | Micronesia, Fed. Sts. | Kyrgyz Republic | North America | Central African Republic |
# Korea, Dem. People’s Rep. | Rwanda | Serbia | Thailand | Timor-Leste | Oman | Tanzania |
# Lesotho | Denmark | Mauritius | Middle East & North Africa (excluding high income) | Finland | Lower middle income | Middle East & North Africa |
# El Salvador | Sweden | South Africa | Belgium | Argentina | Nauru | Togo |
# Zimbabwe | Senegal | East Asia & Pacific (excluding high income) | Sub-Saharan Africa (excluding high income) | Uruguay | Low & middle income | Heavily indebted poor countries (HIPC) |
# Europe & Central Asia (IDA & IBRD countries) | Seychelles | Cambodia | Bahamas, The | Post-demographic dividend | Chad | Algeria |
# New Zealand | Suriname | Late-demographic dividend | Fragile and conflict affected situations | Puerto Rico | Aruba | Madagascar |
# Ukraine | Japan | Yemen, Rep. | Central Europe and the Baltics | St. Martin (French part) | Least developed countries: UN classification | New Caledonia |
# Mali | Russian Federation | Sao Tome and Principe | Singapore | Kazakhstan | Malawi | Nepal |
# Portugal | Luxembourg | Marshall Islands | Vietnam | Small states |
#
# ##Total No of Countries = 264

# %%
## Analysing the data Structure

Country_to_look_for = 'India'
ylab = "Expeniding in $"
xlab = "Countries"

filter1 = Medical_Expending_Countires_Wise['Country'] == Country_to_look_for
Medical_Expending_Countires_Wise_country_specific = Medical_Expending_Countires_Wise[filter1]
Medical_Expending_Countires_Wise_country_specific                 
#Medical_Expending_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#     Country Country Code                                     Indicator Name  \
# 107   India          IND  Current health expenditure per capita (current...
#
#         Indicator Code  1960  1961  1962  1963  1964  1965  ...       2011  \
# 107  SH.XPD.CHEX.PC.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...  48.722836
#
#           2012       2013       2014       2015       2016       2017  2018  \
# 107  49.051403  56.218464  57.151138  58.966335  60.618382  69.293098   NaN
#
#      2019  Unnamed: 64
# 107   NaN          NaN
#
# [1 rows x 65 columns]

# %%
## Visualisation
df = Medical_Expending_Countires_Wise
            

labels = df['Country Code']
prev_2015 = df['2015']
prev_2016 = df['2016']
prev_2017 = df['2017']
        
title1 = 'Expening on Health for years 2015-2017 '
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(60,20))
rects1 = ax.bar(x-width/2, prev_2015, width, label='prev_2015')
rects2 = ax.bar(x, prev_2016, width, label='prev_2016')
rects3 = ax.bar(x+width/2, prev_2017, width, label='prev_2017')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

plt.show()
