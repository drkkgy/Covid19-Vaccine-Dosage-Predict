# %% [markdown]
# # Medical_Expending_Data_Visualisation

# %%
## Importing important libraries

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=30)
matplotlib.rcParams.update({'font.size': 28})
import math
import datetime as dt
import os
import sys

# %% [markdown]
# ## Utility Functions

# %%
## Visulalization function 
def Visualize(dataset,List_of_count_to_print,title1,ylab,vx=50,vy=30,w=.80):
    df = dataset
    n = 0
    for i in List_of_count_to_print:
        filter1 = df['Country'] == i
        df = df[filter1]
        labels = df['Date']
        conf = df['Confirmed']
        Recov = df['Recovered']
        Death = df['Deaths']
        
        #high = max(conf)
        #low = min(conf)
        
        x = np.arange(len(labels))  # the x label locations 
        width = w  # the width of the bars
        fig, ax = plt.subplots(figsize=(vx,vy))
        rects1 = ax.bar(x - width, conf, width, label='confirmed')
        rects2 = ax.bar(x , Recov, width, label='Recovered')
        rects3 = ax.bar(x + width , Death, width, label='Death')

        # Add some text for labels, title and custom x-axis tick labels, etc.
        ax.set_ylabel(ylab)
        ax.set_title(title1)
        ax.set_xticks(x)
        plt.xticks(rotation=90) 
        #plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
        ax.set_xticklabels(labels)
        ax.legend()
        n  = n + 1
    
    
    plt.show()
    
## function to Check the List of Countries avaialable
def count_avalaible(dataframe,country_coul_rep = 'Country'):
    x = 0
    for i in set(dataframe.loc[:,country_coul_rep]):
        print(i,end=' | ')
        x = x + 1
        if(x > 6):
            x = 0
            print()
    print("\n\n##Total No of Countries = " + str(len(set(dataframe.loc[:,country_coul_rep]))))

# %% [markdown]
# ## Loading Medical_Expending_Data Data

# %%
Medical_Expending_Countires_Wise = pd.read_csv('../../Medical Expending/API_SH.XPD.CHEX.PC.CD_DS2_en_csv_v2_1218407/API_SH.XPD.CHEX.PC.CD_DS2_en_csv_v2_1218407.csv')
Medical_Expending_Countires_Wise
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 1    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 2    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 3    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 4    Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# ..                                                 ...                ...
# 259  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 260  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 261  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 262  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 263  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
#
#      1960  1961  1962  1963  1964  1965  ...         2011         2012  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN  ...          NaN          NaN
# 1     NaN   NaN   NaN   NaN   NaN   NaN  ...    51.553257    52.218510
# 2     NaN   NaN   NaN   NaN   NaN   NaN  ...   122.117798   122.242943
# 3     NaN   NaN   NaN   NaN   NaN   NaN  ...          NaN          NaN
# 4     NaN   NaN   NaN   NaN   NaN   NaN  ...  4013.911865  3857.161133
# ..    ...   ...   ...   ...   ...   ...  ...          ...          ...
# 259   NaN   NaN   NaN   NaN   NaN   NaN  ...          NaN          NaN
# 260   NaN   NaN   NaN   NaN   NaN   NaN  ...    64.361031    73.826073
# 261   NaN   NaN   NaN   NaN   NaN   NaN  ...   597.359436   579.748535
# 262   NaN   NaN   NaN   NaN   NaN   NaN  ...    56.911751    68.191803
# 263   NaN   NaN   NaN   NaN   NaN   NaN  ...    75.418983    75.387726
#
#             2013         2014         2015         2016         2017  2018  \
# 0            NaN          NaN          NaN          NaN          NaN   NaN
# 1      55.967548    60.112759    60.088814    61.451286    67.122650   NaN
# 2     143.703217   131.751877   108.680672    95.220802   114.459641   NaN
# 3            NaN          NaN          NaN          NaN          NaN   NaN
# 4    4107.733887  4346.258301  3695.067871  3843.702881  4040.786621   NaN
# ..           ...          ...          ...          ...          ...   ...
# 259          NaN          NaN          NaN          NaN          NaN   NaN
# 260    78.390152    79.746155    72.039467          NaN          NaN   NaN
# 261   526.499573   509.833221   470.796967   428.296875   499.237549   NaN
# 262    86.819550    66.555664    58.517654    56.544182    67.648666   NaN
# 263    83.089012    99.553772    94.290009    98.579636   110.149620   NaN
#
#      2019  Unnamed: 64
# 0     NaN          NaN
# 1     NaN          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4     NaN          NaN
# ..    ...          ...
# 259   NaN          NaN
# 260   NaN          NaN
# 261   NaN          NaN
# 262   NaN          NaN
# 263   NaN          NaN
#
# [264 rows x 65 columns]

# %%
## Check the List of Countries avaialable

## Columns renaming for Uniformity
Medical_Expending_Countires_Wise = Medical_Expending_Countires_Wise.rename(columns={'Country Name': 'Country'})
count_avalaible(Medical_Expending_Countires_Wise,'Country')
# Out:
# North Macedonia | Armenia | Cambodia | World | Venezuela, RB | IDA total | Montenegro |
# Late-demographic dividend | Fiji | Central African Republic | Canada | Afghanistan | Mongolia | Middle East & North Africa |
# Poland | Ecuador | Azerbaijan | Bosnia and Herzegovina | Czech Republic | Gibraltar | Low & middle income |
# Comoros | Other small states | Samoa | Croatia | Nepal | Senegal | Nauru |
# Burundi | Slovak Republic | Guyana | Saudi Arabia | Burkina Faso | San Marino | Latin America & Caribbean (excluding high income) |
# Liechtenstein | Malaysia | Caribbean small states | Chad | Netherlands | Finland | Pakistan |
# Iceland | Mozambique | Bahamas, The | Namibia | France | Germany | Mauritius |
# Ireland | Ethiopia | Cote d'Ivoire | French Polynesia | Lao PDR | Isle of Man | Malawi |
# Niger | Panama | Maldives | Guatemala | Andorra | Algeria | Cabo Verde |
# Qatar | Sweden | Luxembourg | Bahrain | West Bank and Gaza | Channel Islands | Thailand |
# Europe & Central Asia (excluding high income) | Kazakhstan | India | Syrian Arab Republic | North America | Lebanon | East Asia & Pacific (excluding high income) |
# Norway | Sub-Saharan Africa (excluding high income) | Middle East & North Africa (IDA & IBRD countries) | Chile | Argentina | Micronesia, Fed. Sts. | Papua New Guinea |
#
# ##Total No of Countries = 264

# %%
## Analysing the data Structure

Country_to_look_for = 'India'
ylab = "Expeniding in $"
xlab = "Countries"

filter1 = Medical_Expending_Countires_Wise['Country'] == Country_to_look_for
Medical_Expending_Countires_Wise_country_specific = Medical_Expending_Countires_Wise[filter1]
Medical_Expending_Countires_Wise_country_specific                 
#Medical_Expending_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#     Country Country Code                                     Indicator Name  \
# 107   India          IND  Current health expenditure per capita (current...
#
#         Indicator Code  1960  1961  1962  1963  1964  1965  ...       2011  \
# 107  SH.XPD.CHEX.PC.CD   NaN   NaN   NaN   NaN   NaN   NaN  ...  48.722836
#
#           2012       2013       2014       2015       2016       2017  2018  \
# 107  49.051403  56.218464  57.151138  58.966335  60.618382  69.293098   NaN
#
#      2019  Unnamed: 64
# 107   NaN          NaN
#
# [1 rows x 65 columns]

# %%
## Visualisation
df = Medical_Expending_Countires_Wise
            

labels = df['Country Code']
prev_2015 = df['2015']
prev_2016 = df['2016']
prev_2017 = df['2017']
        
title1 = 'Expening on Health for years 2015-2017 '
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(60,20))
rects1 = ax.bar(x-width/2, prev_2015, width, label='prev_2015')
rects2 = ax.bar(x, prev_2016, width, label='prev_2016')
rects3 = ax.bar(x+width/2, prev_2017, width, label='prev_2017')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %% [markdown]
# ## Cleaning Mdeical Expending DATA(Preprocessing)

# %% [markdown]
# ##  Writing the cleaned data in Cleaned Folder

# %%
Medical_Expending_Countires_Wise.to_csv('../Pre_Processed_Data/Medical_Expending_Countires_Wise_Processed.csv')

# %% [markdown]
# ## Visualisation After Cleaning

# %%
## Visualisation
df = Medical_Expending_Countires_Wise
            

labels = df['Country Code']
prev_2015 = df['2015']
prev_2016 = df['2016']
prev_2017 = df['2017']
        
title1 = 'Expening on Health for years 2015-2017 '
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(60,20))
rects1 = ax.bar(x-width/2, prev_2015, width, label='prev_2015')
rects2 = ax.bar(x, prev_2016, width, label='prev_2016')
rects3 = ax.bar(x+width/2, prev_2017, width, label='prev_2017')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

plt.show()
