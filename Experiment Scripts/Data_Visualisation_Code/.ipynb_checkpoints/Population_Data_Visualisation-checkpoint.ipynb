# %% [markdown]
# # Population_Data_Visualisation

# %%
## Importing important libraries

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=30)
matplotlib.rcParams.update({'font.size': 28})
import math
import datetime as dt
import os
import sys

# %% [markdown]
# ## Utility Functions

# %%
## Visulalization function 
def Visualize(dataset,List_of_count_to_print,title1,ylab,vx=50,vy=30,w=.80):
    df = dataset
    n = 0
    for i in List_of_count_to_print:
        filter1 = df['Country'] == i
        df = df[filter1]
        labels = df['Date']
        conf = df['Confirmed']
        Recov = df['Recovered']
        Death = df['Deaths']
        
        #high = max(conf)
        #low = min(conf)
        
        x = np.arange(len(labels))  # the x label locations 
        width = w  # the width of the bars
        fig, ax = plt.subplots(figsize=(vx,vy))
        rects1 = ax.bar(x - width, conf, width, label='confirmed')
        rects2 = ax.bar(x , Recov, width, label='Recovered')
        rects3 = ax.bar(x + width , Death, width, label='Death')

        # Add some text for labels, title and custom x-axis tick labels, etc.
        ax.set_ylabel(ylab)
        ax.set_title(title1)
        ax.set_xticks(x)
        plt.xticks(rotation=90) 
        #plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
        ax.set_xticklabels(labels)
        ax.legend()
        n  = n + 1
    
    
    plt.show()
    
## function to Check the List of Countries avaialable
def count_avalaible(dataframe,country_coul_rep = 'Country'):
    x = 0
    for i in set(dataframe.loc[:,country_coul_rep]):
        print(i,end=' | ')
        x = x + 1
        if(x > 6):
            x = 0
            print()
    print("\n\n##Total No of Countries = " + str(len(set(dataframe.loc[:,country_coul_rep]))))

# %% [markdown]
# ## Loading Population_Data Data

# %%
Population_Data_Countires_Wise_descreet = pd.read_csv('../../Population_Data/WPP2019_TotalPopulationBySex.csv')
Population_Data_Countires_Wise_descreet
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0           4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1           4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2           4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3           4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4           4  Afghanistan      2       Medium  1954     1954.5   4266.484
# ...       ...          ...    ...          ...   ...        ...        ...
# 280927    716     Zimbabwe    207  Lower 95 PI  2080     2080.5  10576.533
# 280928    716     Zimbabwe    207  Lower 95 PI  2085     2085.5  10293.349
# 280929    716     Zimbabwe    207  Lower 95 PI  2090     2090.5   9920.336
# 280930    716     Zimbabwe    207  Lower 95 PI  2095     2095.5   9503.711
# 280931    716     Zimbabwe    207  Lower 95 PI  2100     2100.5   9090.075
#
#         PopFemale   PopTotal  PopDensity
# 0        3652.874   7752.117      11.874
# 1        3705.395   7840.151      12.009
# 2        3761.546   7935.996      12.156
# 3        3821.348   8039.684      12.315
# 4        3884.832   8151.316      12.486
# ...           ...        ...         ...
# 280927  11255.983  21836.893      56.448
# 280928  11050.875  21355.988      55.205
# 280929  10767.709  20689.956      53.483
# 280930  10412.184  19892.080      51.421
# 280931   9996.105  19061.177      49.273
#
# [280932 rows x 10 columns]

# %%
## Check the List of Countries avaialable
##
full_pop_data = Population_Data_Countires_Wise_descreet
##

## Columns renaming for Uniformity
Population_Data_Countires_Wise_descreet = Population_Data_Countires_Wise_descreet.rename(columns={'Location': 'Country'})
count_avalaible(Population_Data_Countires_Wise_descreet,'Country')
# Out:
# Fiji | Democratic Republic of the Congo | Guatemala | Central Asia | Burkina Faso | Land-locked Countries | Côte d'Ivoire |
# Least developed countries | Mali | Malaysia | Eritrea | Australia/New Zealand | ESCWA: Arab least developed countries | Belt-Road Initiative: Africa |
# ESCAP: lower middle HDI | UNFPA Regions | Ghana | Panama | Lao People's Democratic Republic | Land-locked Countries (Others) | Kenya |
# British Virgin Islands | Niue | Paraguay | Thailand | UNICEF Programme Regions: Middle East and North Africa (MENARO) | Saint Kitts and Nevis | Equatorial Guinea |
# Palau | North Macedonia | Congo | UNICEF Regions: Middle East and North Africa | LLDC: Asia | UNICEF REGIONS | Eswatini |
# Less developed regions, excluding China | Pakistan | Africa | Countries with Access to the Sea | UNICEF Regions: Western Europe | ESCWA: Mashreq countries | Egypt |
# Least developed: Asia | Kazakhstan | Latin America and the Caribbean | Latin American and Caribbean Group (GRULAC) | Hungary | ESCAP region: North and Central Asia | Eastern Africa |
# Vanuatu | Mongolia | Organization of the Islamic Conference (OIC) | Middle-income countries | Southern Asia | Asia | Libya |
# Group of Twenty (G20) - member states | United States of America (and dependencies) | ESCAP region: Pacific | ESCAP: HDI groups | UNICEF Regions: Europe and Central Asia | China | Eurasian Economic Community (Eurasec) |
# Ukraine | ESCAP: lower middle income | Low-income countries | New Zealand (and dependencies) | Southern Common Market (MERCOSUR) | Land-locked Developing Countries (LLDC) | Guadeloupe |
# Marshall Islands | African Union: Northern Africa | Republic of Moldova | Réunion | Syrian Arab Republic | Small Island Developing States (SIDS) | France |
# Azerbaijan | United States of America | Sint Maarten (Dutch part) | UNICEF Regions: Latin America and Caribbean | Zimbabwe | Colombia | Isle of Man |
# ESCAP: WB Low income econ. | WHO: South-East Asia region (SEARO) | Cyprus | United Kingdom | ESCAP: high HDI | Cook Islands | Oceania (excluding Australia and New Zealand) |
# European Union (EU: 15) | More developed: Asia | UNICEF Regions: Eastern Europe and Central Asia | WHO: Eastern Mediterranean Region (EMRO) | Yemen | Dominica | ECLAC: Latin America |
# Chile | Commonwealth: Asia | WB region: Middle East and North Africa (excluding high income) | North Atlantic Treaty Organization (NATO) | Georgia | Organization for Security and Co-operation in Europe (OSCE) | Oman |
# Suriname | Netherlands (and dependencies) | Montenegro | Czechia | Group of Eight (G8) | Mauritius | New Caledonia |
# Upper-middle-income countries | United Nations Economic Commission for Africa (UN-ECA) | Peru | Bahamas | Central European Free Trade Agreement (CEFTA) | Gulf Cooperation Council (GCC) | Commonwealth: Africa |
# Portugal | Antigua and Barbuda | Countries with Access to the Sea: Northern America | LLDC: Africa | Monaco | ESCWA: Maghreb countries | New EU member states (joined since 2004) |
# Germany | Least developed: Africa | Grenada | ESCAP: ADB Developing member countries (DMCs) | Organization of Petroleum Exporting countries (OPEC) | WHO: European Region (EURO) | ECLAC: The Caribbean |
# UNICEF Regions: Sub-Saharan Africa | WHO Regions | Sao Tome and Principe | United Nations Economic and Social Commission for Asia and the Pacific (UN-ESCAP) Regions | Honduras | Philippines | North American Free Trade Agreement (NAFTA) |
# Andorra | Denmark (and dependencies) | ESCAP: income groups | Eastern Asia | Northern Europe | Timor-Leste | Group of 77 (G77) |
# Western Sahara | Estonia | Argentina | Bulgaria | Saint Barthélemy | Latvia | Rwanda |
# Norway | Switzerland | Eastern European Group | ESCAP: ADB Group C (Regular OCR only) | Slovenia | Turks and Caicos Islands | ESCAP: low income |
# Bolivia (Plurinational State of) | Netherlands | United Republic of Tanzania | Cuba | UNICEF Programme Regions: West and Central Africa (WCARO) | African Union: Western Africa | Caribbean Community and Common Market (CARICOM) |
# More developed: Oceania | UNFPA: East and Southern Africa (ESA) | Bolivarian Alliance for the Americas (ALBA) | Morocco | Northern America | League of Arab States (LAS, informal name: Arab League) | African Union: Central Africa |
# Europe and Northern America | Asia-Pacific Group | Qatar | UNFPA: Eastern Europe and Central Asia (EECA) | Middle Africa | Sudan | UNICEF Programme Regions: Eastern Caribbean |
# Micronesia (Fed. States of) | West African Economic and Monetary Union (UEMOA) | ESCAP: Pacific island dev. econ. | Countries with Access to the Sea: Latin America and the Caribbean | ESCAP: Landlocked countries (LLDCs) | Nauru | Australia |
# Western Europe | Denmark | Angola | BRICS | Belt-Road Initiative: Asia | Tunisia | Countries with Access to the Sea: Africa |
# UNFPA: Latin America and the Caribbean (LAC) | UNICEF Regions: North America | Belarus | Montserrat | Ecuador | Countries with Access to the Sea: Asia | Indonesia |
# UNICEF Regions: West and Central Africa | Caribbean | China (and dependencies) | Southern Europe | Asia-Pacific Economic Cooperation (APEC) | United Nations Member States | Aruba |
# Brazil | Trinidad and Tobago | African Union | China, Macao SAR | ESCAP region: East and North-East Asia | Bonaire, Sint Eustatius and Saba | LLDC: Europe |
# Seychelles | Bosnia and Herzegovina | Liechtenstein | United States Virgin Islands | Tokelau | Sierra Leone | Countries with Access to the Sea: Oceania |
# Black Sea Economic Cooperation (BSEC) | American Samoa | Economic Community of West African States (ECOWAS) | Kuwait | State of Palestine | Commonwealth: Caribbean and Americas | Commonwealth: Pacific |
# Falkland Islands (Malvinas) | Western Africa | Andean Community | South Africa | ESCAP: WB High income econ. | ESCWA: Arab countries | ESCAP: Least Developed Countries (LDCs) |
# Eastern Europe | Least developed: Oceania | Northern Africa and Western Asia | Romania | WHO: Western Pacific region (WPRO) | China, Hong Kong SAR | Mozambique |
# UNICEF Regions: Eastern and Southern Africa | ESCAP: upper middle income | Gambia | Togo | Bahrain | Spain | ESCAP: other Asia-Pacific countries/areas |
# Japan | Dem. People's Republic of Korea | Cayman Islands | UNICEF Regions: East Asia and Pacific | Lithuania | Botswana | WB region: South Asia (excluding high income) |
# Northern Africa | Iceland | Commonwealth of Independent States (CIS) | Kiribati | ESCAP: ASEAN | Belt-Road Initiative (BRI) | Austria |
# Latin American Integration Association (ALADI) | Curaçao | ESCAP: WB Lower middle income econ. | ESCAP: Central Asia | South Asian Association for Regional Cooperation (SAARC) | Dominican Republic | Bhutan |
# Anguilla | Channel Islands | Sweden | More developed regions | UNICEF Programme Regions: Latin America | Djibouti | El Salvador |
# Association of Southeast Asian Nations (ASEAN) | Group of Seven (G7) | Israel | Belize | Benin | Cambodia | Zambia |
# Tajikistan | Namibia | Poland | South America | Croatia | Less developed: Latin America and the Caribbean | Southern African Development Community (SADC) |
# No income group available | Venezuela (Bolivarian Republic of) | Turkey | Guam | World Bank Regional Groups (developing only) | UNICEF Regions: South Asia | UNICEF Programme Regions: Europe and Central Asia (CEECIS) |
# Algeria | Less developed regions, excluding least developed countries | United Nations Economic Commission for Latin America and the Caribbean (UN-ECLAC) | Saint Martin (French part) | Central African Republic | ESCAP: WB income groups | Liberia |
# Malawi | Tonga | India | ESCAP: high income | Commonwealth: Europe | WB region: Sub-Saharan Africa (excluding high income) | UNICEF Programme Regions: East Asia and Pacific (EAPRO) |
# Slovakia | African, Caribbean and Pacific (ACP) Group of States | Ethiopia | Turkmenistan | East African Community (EAC) | UNICEF Programme Regions: Latin America and Caribbean (LACRO) | ECE: North America-2 |
# Papua New Guinea | Italy | Gabon | UNFPA: West and Central Africa (WCA) | Uruguay | Jamaica | Haiti |
# Least developed: Latin America and the Caribbean | Cameroon | Saint Helena | France (and dependencies) | Chad | Armenia | ESCAP: WB Upper middle income econ. |
# Malta | UNFPA: Asia and the Pacific (AP) | ESCAP: ECO | More developed: Northern America | Brunei Darussalam | Northern Mariana Islands | Uzbekistan |
# UNICEF PROGRAMME REGIONS | Mayotte | Oceania | Costa Rica | Mexico | ESCAP region: South-East Asia | Countries with Access to the Sea: Europe |
# Gibraltar | Puerto Rico | Iran (Islamic Republic of) | Comoros | Nicaragua | San Marino | Maldives |
# Bangladesh | ESCWA: Gulf Cooperation Council countries | Mauritania | Belt-Road Initiative: Pacific | Europe (48) | United Arab Emirates | Luxembourg |
# ESCAP: low HDI | Central America | Organisation for Economic Co-operation and Development (OECD) | Nepal | ESCAP: SAARC | French Guiana | Canada |
# New Zealand | Less developed: Africa | Organization of American States (OAS) | Faroe Islands | European Free Trade Agreement (EFTA) | South Sudan | Afghanistan |
# Finland | Lower-middle-income countries | Micronesia | Iraq | European Community (EC: 12) | UNICEF Programme Regions: South Asia (ROSA) | Singapore |
# Uganda | Myanmar | UN-ECE: member countries | ESCAP region: South and South-West Asia | ESCAP: ADB Group A (Concessional assistance only) | Wallis and Futuna Islands | Economic Cooperation Organization (ECO) |
# South-Eastern Asia | Non-Self-Governing Territories | African Group | ECE: UNECE-52 | Shanghai Cooperation Organization (SCO) | Saint Vincent and the Grenadines | Republic of Korea |
# Commonwealth of Nations | WB region: East Asia and Pacific (excluding high income) | WHO: Americas (AMRO) | French Polynesia | Western European and Others Group (WEOG) | WB region: Latin America and Caribbean (excluding high income) | Guinea |
# Belgium | Eastern and South-Eastern Asia | Bermuda | Serbia | Europe | Less developed regions | Samoa |
# Burundi | China, Taiwan Province of China | ESCAP: ADB Group B (OCR blend) | Lebanon | Solomon Islands | SIDS Caribbean | Greenland |
# BRIC | Less developed: Asia | World | More developed: Europe | Jordan | Guyana | African Union: Southern Africa |
# Belt-Road Initiative: Europe | Polynesia | ESCWA: member countries | Ireland | Martinique | WB region: Europe and Central Asia (excluding high income) | Russian Federation |
# Saudi Arabia | SIDS Atlantic, and Indian Ocean, Mediterranean and South China Sea (AIMS) | European Union (EU: 28) | UNFPA: Arab States (AS) | Cabo Verde | Greater Arab Free Trade Area (GAFTA) | Guinea-Bissau |
# Tuvalu | Albania | Nigeria | Kyrgyzstan | African Union: Eastern Africa | High-income countries | Barbados |
# Less developed: Oceania | Central and Southern Asia | LLDC: Latin America | Madagascar | Viet Nam | Lesotho | Holy See |
# UNITED NATIONS Regional Groups of Member States | Belt-Road Initiative: Latin America and the Caribbean | Somalia | SIDS Pacific | United Kingdom (and dependencies) | Southern Africa | Saint Pierre and Miquelon |
# Niger | Senegal | Economic Community of Central African States (ECCAS) | Greece | WHO: African region (AFRO) | Sri Lanka | Sub-Saharan Africa |
# Western Asia | Saint Lucia | Melanesia | UNICEF Programme Regions: Eastern and Southern Africa (ESARO) | ESCAP: upper middle HDI |
#
# ##Total No of Countries = 474

# %%
Population_Data_Countires_Wise = pd.read_csv('../../Population_Data/WPP2019_PopulationBySingleAgeSex_1950-2019.csv')
Population_Data_Countires_Wise
# Out:
#          LocID     Location  VarID Variant  Time  MidPeriod  AgeGrp  \
# 0            4  Afghanistan      2  Medium  1950     1950.5       0
# 1            4  Afghanistan      2  Medium  1950     1950.5       1
# 2            4  Afghanistan      2  Medium  1950     1950.5       2
# 3            4  Afghanistan      2  Medium  1950     1950.5       3
# 4            4  Afghanistan      2  Medium  1950     1950.5       4
# ...        ...          ...    ...     ...   ...        ...     ...
# 3132005    716     Zimbabwe      2  Medium  2019     2019.5      96
# 3132006    716     Zimbabwe      2  Medium  2019     2019.5      97
# 3132007    716     Zimbabwe      2  Medium  2019     2019.5      98
# 3132008    716     Zimbabwe      2  Medium  2019     2019.5      99
# 3132009    716     Zimbabwe      2  Medium  2019     2019.5     100
#
#          AgeGrpStart  AgeGrpSpan  PopMale  PopFemale  PopTotal
# 0                  0           1  139.669    154.913   294.582
# 1                  1           1  131.916    141.851   273.767
# 2                  2           1  125.127    130.632   255.759
# 3                  3           1  119.220    121.097   240.317
# 4                  4           1  114.112    113.085   227.197
# ...              ...         ...      ...        ...       ...
# 3132005           96           1    0.019      0.120     0.139
# 3132006           97           1    0.013      0.083     0.096
# 3132007           98           1    0.006      0.043     0.049
# 3132008           99           1    0.002      0.015     0.017
# 3132009          100          -1    0.002      0.018     0.020
#
# [3132010 rows x 12 columns]

# %%
## Check the List of Countries avaialable
##
full_pop_data = Population_Data_Countires_Wise
##

## Columns renaming for Uniformity
Population_Data_Countires_Wise = Population_Data_Countires_Wise.rename(columns={'Location': 'Country'})
count_avalaible(Population_Data_Countires_Wise,'Country')
# Out:
# Fiji | Democratic Republic of the Congo | Guatemala | Central Asia | Burkina Faso | Land-locked Countries | Côte d'Ivoire |
# Least developed countries | Mali | Malaysia | Eritrea | Australia/New Zealand | ESCWA: Arab least developed countries | Belt-Road Initiative: Africa |
# ESCAP: lower middle HDI | UNFPA Regions | Ghana | Panama | Lao People's Democratic Republic | Land-locked Countries (Others) | Kenya |
# Paraguay | Thailand | UNICEF Programme Regions: Middle East and North Africa (MENARO) | Equatorial Guinea | North Macedonia | Congo | UNICEF Regions: Middle East and North Africa |
# LLDC: Asia | UNICEF REGIONS | Eswatini | Less developed regions, excluding China | Pakistan | Africa | Countries with Access to the Sea |
# UNICEF Regions: Western Europe | ESCWA: Mashreq countries | Egypt | Least developed: Asia | Kazakhstan | Latin America and the Caribbean | Latin American and Caribbean Group (GRULAC) |
# Hungary | ESCAP region: North and Central Asia | Eastern Africa | Vanuatu | Mongolia | Organization of the Islamic Conference (OIC) | Middle-income countries |
# Southern Asia | Asia | Libya | Group of Twenty (G20) - member states | United States of America (and dependencies) | ESCAP region: Pacific | ESCAP: HDI groups |
# UNICEF Regions: Europe and Central Asia | China | Eurasian Economic Community (Eurasec) | Ukraine | ESCAP: lower middle income | Low-income countries | New Zealand (and dependencies) |
# Southern Common Market (MERCOSUR) | Land-locked Developing Countries (LLDC) | Guadeloupe | Republic of Moldova | African Union: Northern Africa | Réunion | Syrian Arab Republic |
# Small Island Developing States (SIDS) | France | Azerbaijan | United States of America | UNICEF Regions: Latin America and Caribbean | Zimbabwe | Colombia |
# ESCAP: WB Low income econ. | WHO: South-East Asia region (SEARO) | Cyprus | United Kingdom | ESCAP: high HDI | Oceania (excluding Australia and New Zealand) | European Union (EU: 15) |
# More developed: Asia | UNICEF Regions: Eastern Europe and Central Asia | WHO: Eastern Mediterranean Region (EMRO) | Yemen | ECLAC: Latin America | Chile | Commonwealth: Asia |
# WB region: Middle East and North Africa (excluding high income) | North Atlantic Treaty Organization (NATO) | Georgia | Organization for Security and Co-operation in Europe (OSCE) | Oman | Suriname | Netherlands (and dependencies) |
# Montenegro | Czechia | Group of Eight (G8) | Mauritius | New Caledonia | Upper-middle-income countries | United Nations Economic Commission for Africa (UN-ECA) |
# Peru | Bahamas | Central European Free Trade Agreement (CEFTA) | Gulf Cooperation Council (GCC) | Commonwealth: Africa | Portugal | Antigua and Barbuda |
# Countries with Access to the Sea: Northern America | LLDC: Africa | ESCWA: Maghreb countries | New EU member states (joined since 2004) | Germany | Least developed: Africa | Grenada |
# ESCAP: ADB Developing member countries (DMCs) | Organization of Petroleum Exporting countries (OPEC) | WHO: European Region (EURO) | ECLAC: The Caribbean | UNICEF Regions: Sub-Saharan Africa | WHO Regions | Sao Tome and Principe |
# United Nations Economic and Social Commission for Asia and the Pacific (UN-ESCAP) Regions | Honduras | Philippines | North American Free Trade Agreement (NAFTA) | Denmark (and dependencies) | ESCAP: income groups | Eastern Asia |
# Northern Europe | Timor-Leste | Group of 77 (G77) | Western Sahara | Estonia | Argentina | Bulgaria |
# Latvia | Rwanda | Norway | Switzerland | Eastern European Group | ESCAP: ADB Group C (Regular OCR only) | Slovenia |
# ESCAP: low income | Bolivia (Plurinational State of) | Netherlands | United Republic of Tanzania | Cuba | UNICEF Programme Regions: West and Central Africa (WCARO) | African Union: Western Africa |
# Caribbean Community and Common Market (CARICOM) | More developed: Oceania | UNFPA: East and Southern Africa (ESA) | Bolivarian Alliance for the Americas (ALBA) | Morocco | Northern America | League of Arab States (LAS, informal name: Arab League) |
# African Union: Central Africa | Europe and Northern America | Asia-Pacific Group | Qatar | UNFPA: Eastern Europe and Central Asia (EECA) | Middle Africa | Sudan |
# UNICEF Programme Regions: Eastern Caribbean | Micronesia (Fed. States of) | West African Economic and Monetary Union (UEMOA) | ESCAP: Pacific island dev. econ. | Countries with Access to the Sea: Latin America and the Caribbean | ESCAP: Landlocked countries (LLDCs) | Australia |
# Western Europe | Denmark | Angola | BRICS | Belt-Road Initiative: Asia | Tunisia | Countries with Access to the Sea: Africa |
# UNFPA: Latin America and the Caribbean (LAC) | UNICEF Regions: North America | Belarus | Ecuador | Countries with Access to the Sea: Asia | Indonesia | UNICEF Regions: West and Central Africa |
# Caribbean | China (and dependencies) | Southern Europe | Asia-Pacific Economic Cooperation (APEC) | United Nations Member States | Aruba | Brazil |
# Trinidad and Tobago | African Union | China, Macao SAR | ESCAP region: East and North-East Asia | LLDC: Europe | Seychelles | Bosnia and Herzegovina |
# United States Virgin Islands | Sierra Leone | Countries with Access to the Sea: Oceania | Black Sea Economic Cooperation (BSEC) | Economic Community of West African States (ECOWAS) | Kuwait | State of Palestine |
# Commonwealth: Caribbean and Americas | Commonwealth: Pacific | Western Africa | Andean Community | South Africa | ESCAP: WB High income econ. | ESCWA: Arab countries |
# ESCAP: Least Developed Countries (LDCs) | Eastern Europe | Least developed: Oceania | Northern Africa and Western Asia | Romania | WHO: Western Pacific region (WPRO) | China, Hong Kong SAR |
# Mozambique | UNICEF Regions: Eastern and Southern Africa | ESCAP: upper middle income | Gambia | Togo | Bahrain | Spain |
# ESCAP: other Asia-Pacific countries/areas | Japan | Dem. People's Republic of Korea | UNICEF Regions: East Asia and Pacific | Lithuania | Botswana | WB region: South Asia (excluding high income) |
# Northern Africa | Iceland | Commonwealth of Independent States (CIS) | Kiribati | ESCAP: ASEAN | Belt-Road Initiative (BRI) | Austria |
# Latin American Integration Association (ALADI) | Curaçao | ESCAP: WB Lower middle income econ. | ESCAP: Central Asia | South Asian Association for Regional Cooperation (SAARC) | Dominican Republic | Bhutan |
# Channel Islands | Sweden | More developed regions | UNICEF Programme Regions: Latin America | Djibouti | El Salvador | Association of Southeast Asian Nations (ASEAN) |
# Group of Seven (G7) | Israel | Belize | Benin | Cambodia | Zambia | Tajikistan |
# Namibia | Poland | South America | Croatia | Less developed: Latin America and the Caribbean | Southern African Development Community (SADC) | No income group available |
# Venezuela (Bolivarian Republic of) | Turkey | Guam | World Bank Regional Groups (developing only) | UNICEF Regions: South Asia | UNICEF Programme Regions: Europe and Central Asia (CEECIS) | Algeria |
# Less developed regions, excluding least developed countries | United Nations Economic Commission for Latin America and the Caribbean (UN-ECLAC) | Central African Republic | ESCAP: WB income groups | Liberia | Malawi | Tonga |
# India | ESCAP: high income | Commonwealth: Europe | WB region: Sub-Saharan Africa (excluding high income) | UNICEF Programme Regions: East Asia and Pacific (EAPRO) | Slovakia | African, Caribbean and Pacific (ACP) Group of States |
# Ethiopia | Turkmenistan | East African Community (EAC) | UNICEF Programme Regions: Latin America and Caribbean (LACRO) | ECE: North America-2 | Papua New Guinea | Italy |
# Gabon | UNFPA: West and Central Africa (WCA) | Uruguay | Jamaica | Haiti | Least developed: Latin America and the Caribbean | Cameroon |
# France (and dependencies) | Chad | Armenia | ESCAP: WB Upper middle income econ. | Malta | UNFPA: Asia and the Pacific (AP) | ESCAP: ECO |
# More developed: Northern America | Brunei Darussalam | Uzbekistan | UNICEF PROGRAMME REGIONS | Mayotte | Oceania | Costa Rica |
# Mexico | ESCAP region: South-East Asia | Countries with Access to the Sea: Europe | Puerto Rico | Iran (Islamic Republic of) | Comoros | Nicaragua |
# Maldives | Bangladesh | ESCWA: Gulf Cooperation Council countries | Mauritania | Belt-Road Initiative: Pacific | Europe (48) | United Arab Emirates |
# Luxembourg | ESCAP: low HDI | Central America | Organisation for Economic Co-operation and Development (OECD) | Nepal | ESCAP: SAARC | French Guiana |
# Canada | New Zealand | Less developed: Africa | Organization of American States (OAS) | European Free Trade Agreement (EFTA) | South Sudan | Afghanistan |
# Finland | Lower-middle-income countries | Micronesia | Iraq | European Community (EC: 12) | UNICEF Programme Regions: South Asia (ROSA) | Singapore |
# Uganda | Myanmar | UN-ECE: member countries | ESCAP region: South and South-West Asia | ESCAP: ADB Group A (Concessional assistance only) | Economic Cooperation Organization (ECO) | South-Eastern Asia |
# Non-Self-Governing Territories | African Group | ECE: UNECE-52 | Shanghai Cooperation Organization (SCO) | Saint Vincent and the Grenadines | Republic of Korea | Commonwealth of Nations |
# WB region: East Asia and Pacific (excluding high income) | WHO: Americas (AMRO) | French Polynesia | Western European and Others Group (WEOG) | WB region: Latin America and Caribbean (excluding high income) | Guinea | Belgium |
# Eastern and South-Eastern Asia | Serbia | Europe | Less developed regions | Samoa | Burundi | China, Taiwan Province of China |
# ESCAP: ADB Group B (OCR blend) | Lebanon | Solomon Islands | SIDS Caribbean | BRIC | Less developed: Asia | World |
# More developed: Europe | Jordan | Guyana | African Union: Southern Africa | Belt-Road Initiative: Europe | Polynesia | ESCWA: member countries |
# Ireland | Martinique | WB region: Europe and Central Asia (excluding high income) | Russian Federation | Saudi Arabia | SIDS Atlantic, and Indian Ocean, Mediterranean and South China Sea (AIMS) | European Union (EU: 28) |
# UNFPA: Arab States (AS) | Cabo Verde | Greater Arab Free Trade Area (GAFTA) | Guinea-Bissau | Albania | Nigeria | Kyrgyzstan |
# African Union: Eastern Africa | High-income countries | Barbados | Less developed: Oceania | Central and Southern Asia | LLDC: Latin America | Madagascar |
# Viet Nam | Lesotho | UNITED NATIONS Regional Groups of Member States | Belt-Road Initiative: Latin America and the Caribbean | Somalia | SIDS Pacific | United Kingdom (and dependencies) |
# Southern Africa | Niger | Senegal | Economic Community of Central African States (ECCAS) | Greece | WHO: African region (AFRO) | Sri Lanka |
# Sub-Saharan Africa | Western Asia | Saint Lucia | Melanesia | UNICEF Programme Regions: Eastern and Southern Africa (ESARO) | ESCAP: upper middle HDI |
#
# ##Total No of Countries = 440

# %%
## Analysing the data Structure
Country_to_look_for = 'India'
Year_to_look_for = 2019
ylab = "Population"
xlab = "Year"



filter1 = Population_Data_Countires_Wise['Country'] == Country_to_look_for
Population_Data_Countires_Wise_country_specific = Population_Data_Countires_Wise[filter1]
filter2 = Population_Data_Countires_Wise_country_specific['Time'] == Year_to_look_for
Population_Data_Countires_Wise_country_specific = Population_Data_Countires_Wise_country_specific[filter2]
Population_Data_Countires_Wise_country_specific
#Population_Data_Countires_Wise  ## Uncomment this to view for all countires at once
# Out:
#          LocID Country  VarID Variant  Time  MidPeriod  AgeGrp  AgeGrpStart  \
# 1420969    356   India      2  Medium  2019     2019.5       0            0
# 1420970    356   India      2  Medium  2019     2019.5       1            1
# 1420971    356   India      2  Medium  2019     2019.5       2            2
# 1420972    356   India      2  Medium  2019     2019.5       3            3
# 1420973    356   India      2  Medium  2019     2019.5       4            4
# ...        ...     ...    ...     ...   ...        ...     ...          ...
# 1421065    356   India      2  Medium  2019     2019.5      96           96
# 1421066    356   India      2  Medium  2019     2019.5      97           97
# 1421067    356   India      2  Medium  2019     2019.5      98           98
# 1421068    356   India      2  Medium  2019     2019.5      99           99
# 1421069    356   India      2  Medium  2019     2019.5     100          100
#
#          AgeGrpSpan    PopMale  PopFemale   PopTotal
# 1420969           1  12518.937  11385.787  23904.724
# 1420970           1  12303.679  11187.267  23490.946
# 1420971           1  12179.091  11070.664  23249.755
# 1420972           1  12133.716  11025.350  23159.066
# 1420973           1  12049.429  10927.902  22977.331
# ...             ...        ...        ...        ...
# 1421065           1     27.444     37.908     65.352
# 1421066           1     20.203     28.635     48.838
# 1421067           1     12.618     19.099     31.717
# 1421068           1      7.794     12.509     20.303
# 1421069          -1     15.806     28.978     44.784
#
# [101 rows x 12 columns]

# %%
## Visualisation

df = Population_Data_Countires_Wise_country_specific
            

labels = df['AgeGrp']
prev_PopMale = df['PopMale']
prev_PopFemale = df['PopFemale']
prev_PopTotal = df['PopTotal']
        
title1 = 'Population in ' + str(Country_to_look_for) + ' and year = ' + str(Year_to_look_for)
         
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(40,30))
rects1 = ax.bar(x-width/2, prev_PopMale, width, label='PopMale')
rects2 = ax.bar(x, prev_PopFemale, width, label='PopFemale')
rects3 = ax.bar(x+width/2, prev_PopTotal, width, label='PopTotal')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

    
    
plt.show()

# %% [markdown]
# ## Cleaning Population DATA(Preprocessing)

# %%
Population_Data_Countires_Wise = Population_Data_Countires_Wise.replace('United States of America', 'US')
Population_Data_Countires_Wise_descreet = Population_Data_Countires_Wise_descreet.replace('United States of America', 'US')

# %%
## Column match

print('-----------------------------------------------------------------')

countries = ['Afghanistan','Italy' , 'Kuwait', 'India', 'South Africa' ,'US', 
             'United Kingdom','Sri Lanka', 'Chile' , 'Norway', 'New Zealand' ,'Switzerland', 
'Australia', 'Canada', 'China','Slovenia','North Macedonia']
k = 0

match = []
for i in set(Population_Data_Countires_Wise.loc[:,'Country']):
    if(i in countries):
        k +=1
        match.append(i)
        print(i)
        
print(k)
print("-------Not Matching --------------------")
for i in countries:
    if(i not in match ):
        print(i)
# Out:
# -----------------------------------------------------------------
# North Macedonia
# China
# United Kingdom
# Chile
# Norway
# Switzerland
# Slovenia
# Australia
# Kuwait
# South Africa
# US
# India
# Italy
# Canada
# New Zealand
# Afghanistan
# Sri Lanka
# 17
# -------Not Matching --------------------

# %%
## Column match

print('-----------------------------------------------------------------')

countries = ['Afghanistan','Italy' , 'Kuwait', 'India', 'South Africa' ,'US', 
             'United Kingdom','Sri Lanka', 'Chile' , 'Norway', 'New Zealand' ,'Switzerland', 
'Australia', 'Canada', 'China','Slovenia','North Macedonia']
k = 0

match = []
for i in set(Population_Data_Countires_Wise_descreet.loc[:,'Country']):
    if(i in countries):
        k +=1
        match.append(i)
        print(i)
        
print(k)
print("-------Not Matching --------------------")
for i in countries:
    if(i not in match ):
        print(i)
# Out:
# -----------------------------------------------------------------
# North Macedonia
# China
# United Kingdom
# Chile
# Norway
# Switzerland
# Slovenia
# Australia
# Kuwait
# South Africa
# US
# India
# Italy
# Canada
# New Zealand
# Afghanistan
# Sri Lanka
# 17
# -------Not Matching --------------------

# %%
Population_Data_Countires_Wise_descreet_processed = Population_Data_Countires_Wise_descreet[
    Population_Data_Countires_Wise_descreet['Time'] == 2020 ]
Population_Data_Countires_Wise_descreet_processed = Population_Data_Countires_Wise_descreet_processed[ Population_Data_Countires_Wise_descreet_processed['Variant'] == 'Medium']
Population_Data_Countires_Wise_descreet_processed
# Out:
#         LocID                                       Country  VarID Variant  \
# 70          4                                   Afghanistan      2  Medium
# 954       903                                        Africa      2  Medium
# 1838     1823                                 African Group      2  Medium
# 1989     1560                                 African Union      2  Medium
# 2140     2080                 African Union: Central Africa      2  Medium
# ...       ...                                           ...    ...     ...
# 277315    900                                         World      2  Medium
# 278199   1801  World Bank Regional Groups (developing only)      2  Medium
# 278350    887                                         Yemen      2  Medium
# 279234    894                                        Zambia      2  Medium
# 280118    716                                      Zimbabwe      2  Medium
#
#         Time  MidPeriod      PopMale    PopFemale     PopTotal  PopDensity
# 70      2020     2020.5    19976.265    18952.076    38928.341      59.627
# 954     2020     2020.5   669878.340   670719.773  1340598.113      45.216
# 1838    2020     2020.5   668995.562   669831.029  1338826.591      45.571
# 1989    2020     2020.5   669307.822   670116.099  1339423.921      45.182
# 2140    2020     2020.5    79260.910    79358.728   158619.638      30.066
# ...      ...        ...          ...          ...          ...         ...
# 277315  2020     2020.5  3929973.953  3864824.776  7794798.729      59.917
# 278199  2020     2020.5  3299567.992  3229194.235  6528762.227      71.088
# 278350  2020     2020.5    15024.985    14800.983    29825.968      56.492
# 279234  2020     2020.5     9103.006     9280.950    18383.956      24.730
# 280118  2020     2020.5     7092.010     7770.917    14862.927      38.420
#
# [477 rows x 10 columns]

# %% [markdown]
# ##  Writing the cleaned data in Cleaned Folder

# %%
Population_Data_Countires_Wise.to_csv('../Pre_Processed_Data/Population_Data_Countires_Wise_Processed.csv')

# %% [markdown]
# ## Visualisation After Cleaning

# %%
## Visualisation

df = Population_Data_Countires_Wise_country_specific
            

labels = df['AgeGrp']
prev_PopMale = df['PopMale']
prev_PopFemale = df['PopFemale']
prev_PopTotal = df['PopTotal']
        
title1 = 'Population in ' + str(Country_to_look_for) + ' and year = ' + str(Year_to_look_for)
         
#high = int(max(prev_2018))
#low = 0  

x = np.arange(len(labels))  # the x label locations 
width = .50  # the width of the bars
fig, ax = plt.subplots(figsize=(40,30))
rects1 = ax.bar(x-width/2, prev_PopMale, width, label='PopMale')
rects2 = ax.bar(x, prev_PopFemale, width, label='PopFemale')
rects3 = ax.bar(x+width/2, prev_PopTotal, width, label='PopTotal')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel(ylab)
ax.set_xlabel(xlab)
ax.set_title(title1)
ax.set_xticks(x)
#ax.set_yticks(y)
plt.xticks(rotation=90) 
#plt.ylim([math.ceil(low-0.5*(high-low)), math.ceil(high+0.5*(high-low))])
ax.set_xticklabels(labels)
ax.legend()

    
    
plt.show()
